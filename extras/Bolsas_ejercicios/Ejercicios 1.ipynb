# %% [markdown]
# # Introducción al Análisis de Datos en Python
# **Profesor:** Santiago Neira Hernández
# **Bolsa de Ejercicios Inicial**
#
# ---
#
# ## Objetivos de aprendizaje
# - Reconocer y manipular **objetos básicos** de Python (int, float, str, bool).
# - Utilizar **estructuras de datos** nativas (list, dict, tuple, set) para organizar información.
# - Definir **funciones** con parámetros, retornos y valores por defecto.
# - Escribir código claro, con **docstrings** y buenas prácticas.
#
# ## Reglas de la clase
# - Comenta tu código cuando sea necesario.
# - Nombra variables con claridad (`snake_case`).
# - Evita copiar/pegar sin entender: ¡experimenta y prueba!
# - Al final hay **ejercicios sin solución** para practicar.
#
# > Nota: Cada bloque marcado como **Ejercicio (guiado)** incluye una propuesta de solución.
# > La última sección **Ejercicios para resolver SIN solución** no incluye respuestas.

# %% [markdown]
# ---
# ## 1. Objetos básicos
#
# ### Ejercicio 1 (guiado): Tipos y `type()`
# Crea variables de diferentes tipos y verifica su tipo:
# 1. Edad (entero)
# 2. Estatura en metros (float)
# 3. Nombre completo (string)
# 4. ¿Eres estudiante? (bool)

# %%
# ✅ Solución propuesta
edad = 27
estatura_m = 1.78
nombre_completo = "Tu Nombre Aquí"
es_estudiante = True

print(type(edad))
print(type(estatura_m))
print(type(nombre_completo))
print(type(es_estudiante))

# %% [markdown]
# ### Ejercicio 2 (guiado): Conversión de tipos (casting)
# Convierte la cadena `"42"` a entero y súmale 8. Convierte el resultado a `str`.

# %%
# ✅ Solución propuesta
x = "42"
y = int(x) + 8
z = str(y)
print(y, type(y))
print(z, type(z))

# %% [markdown]
# ### Ejercicio 3 (guiado): Operaciones y `round`
# Calcula el IMC (Índice de Masa Corporal) con peso y estatura y redondea a 2 decimales.
# Fórmula: `imc = peso_kg / (estatura_m ** 2)`

# %%
# ✅ Solución propuesta
peso_kg = 72.5
estatura_m = 1.78
imc = peso_kg / (estatura_m ** 2)
print(round(imc, 2))

# %% [markdown]
# ### Ejercicio 4 (guiado): Cadenas de texto (strings)
# - Usa f-strings para construir: `"Hola, soy <nombre>, tengo <edad> años."`
# - Extrae el primer nombre (`split`) y conviértelo a mayúsculas.

# %%
# ✅ Solución propuesta
nombre = "Santiago Neira Hernández"
edad = 28
s = f"Hola, soy {nombre}, tengo {edad} años."
print(s)

primer_nombre = nombre.split()[0]
print(primer_nombre.upper())
# Out:
# Hola, soy Santiago Neira Hernández, tengo 28 años.
# SANTIAGO

# %% [markdown]
# ---
# ## 2. Estructuras de datos
#
# ### Ejercicio 5 (guiado): Listas — indexación y slicing
# 1. Crea una lista con 6 ciudades.
# 2. Muestra las 3 primeras, las 3 últimas, y la lista invertida.
# 3. Reemplaza el segundo elemento por otra ciudad.

# %%
# ✅ Solución propuesta
ciudades = ["Bogotá", "Medellín", "Cali", "Cartagena", "Barranquilla", "Bucaramanga"]
print("Primeras 3:", ciudades[:3])
print("Últimas 3:", ciudades[-3:])
print("Invertida:", ciudades[::-1])

ciudades[1] = "Manizales"
ciudades

# %% [markdown]
# ### Ejercicio 6 (guiado): List Comprehensions
# Con una lista de precios, agrega IVA del 19% a cada precio y deja como resultado una **nueva lista** redondeada a 2 decimales.

# %%
# ✅ Solución propuesta
precios = [1000, 2399, 499.9, 12000, 750.5]
precios_con_iva = [round(p * 1.19, 2) for p in precios]
precios_con_iva

# %% [markdown]
# ### Ejercicio 7 (guiado): Diccionarios — acceso seguro y actualización
# 1. Crea un diccionario `alumno` con `nombre`, `edad`, `programa`.
# 2. Intenta obtener la clave `promedio` usando `get` con valor por defecto `None`.
# 3. Agrega la clave `promedio` con 4.3 y muestra las claves y valores.

# %%
# ✅ Solución propuesta
alumno = {"nombre": "Ana", "edad": 21, "programa": "Economía"}
print("Promedio (antes):", alumno.get("promedio", None))

alumno["promedio"] = 4.3
print("Claves:", list(alumno.keys()))
print("Valores:", list(alumno.values()))
alumno

# %% [markdown]
# ### Ejercicio 8 (guiado): Conjuntos (sets) — elementos únicos
# Dada una lista con repetidos, crea un `set` y cuenta los elementos únicos. Luego vuelve a lista ordenada.

# %%
# ✅ Solución propuesta
muestras = ["py", "r", "sql", "py", "py", "r", "jl"]
unicos = set(muestras)
print("Únicos:", len(unicos), unicos)
ordenados = sorted(list(unicos))
ordenados

# %% [markdown]
# ### Ejercicio 9 (guiado): Tuplas — inmutabilidad
# 1. Crea una tupla `coord = (lat, lon)`.
# 2. Intenta cambiar `coord[0]` y observa el error.
# 3. Explica por qué es útil la inmutabilidad en coordenadas.

# %%
# ✅ Solución propuesta
coord = (4.6097, -74.0817)
try:
    coord[0] = 0.0
except TypeError as e:
    print("Error esperado:", e)
coord

# %% [markdown]
# ---
# ## 3. Funciones
#
# ### Ejercicio 10 (guiado): Función con docstring y anotaciones
# Escribe `def area_triangulo(base: float, altura: float) -> float:` que devuelva el área.

# %%
# ✅ Solución propuesta
def area_triangulo(base: float, altura: float) -> float:
    """Calcula el área de un triángulo.

    Fórmula: 0.5 * base * altura
    """
    return 0.5 * base * altura

area_triangulo(8, 5)

# %% [markdown]
# ### Ejercicio 11 (guiado): Valores por defecto y `*args`, `**kwargs`
# Crea `def potencia(x, y=2)` que eleva `x` a `y`. Demuestra cómo capturar argumentos variables.

# %%
# ✅ Solución propuesta

def potencia(x, y=2):
    return x ** y

print(potencia(3))      # por defecto al cuadrado
print(potencia(2, 10))  # potencia alta

# *args y **kwargs demo

def demo_args(*args, **kwargs):
    print("args:", args)
    print("kwargs:", kwargs)

demo_args(1, 2, 3, nombre="Santiago", curso="Intro Datos")

# %% [markdown]
# ### Ejercicio 12 (guiado): Función que usa otras funciones
# Usa `area_triangulo` dentro de `def area_total(figuras)` que recibe una lista de pares `(base, altura)` y devuelve la suma de áreas.

# %%
# ✅ Solución propuesta

def area_total(figuras):
    total = 0
    for base, altura in figuras:
        total += area_triangulo(base, altura)
    return total

area_total([(3, 4), (10, 2.5), (8, 8)])

# %% [markdown]
# ### Ejercicio 13 (guiado): Lambda, `map`, `filter`
# - Usa `map` para convertir una lista de temperaturas °C a °F.
# - Usa `filter` para quedarte con las temperaturas °F mayores a 80.

# %%
# ✅ Solución propuesta

c = [18, 20, 22, 25, 28, 30]
a_f = list(map(lambda t: (t * 9/5) + 32, c))
calientes = list(filter(lambda f: f > 80, a_f))
a_f, calientes

# %% [markdown]
# ---
# ## 4. Mini‑proyecto (guiado): Resumen de calificaciones
# Tenemos una lista de diccionarios con estudiantes y notas.
# Objetivo: calcular promedio, estado (Aprobado/Reprobado), y el mejor estudiante.

# %%
# ✅ Solución propuesta

datos = [
    {"nombre": "Ana", "notas": [4.5, 3.9, 4.2]},
    {"nombre": "Luis", "notas": [3.2, 3.5, 2.9]},
    {"nombre": "María", "notas": [4.8, 4.7, 4.9]},
]

def promedio(lista):
    return sum(lista) / len(lista) if lista else 0.0

resumen = []
for d in datos:
    prom = promedio(d["notas"])
    estado = "Aprobado" if prom >= 3.0 else "Reprobado"
    resumen.append({"nombre": d["nombre"], "promedio": round(prom, 2), "estado": estado})

print("Resumen:")
for r in resumen:
    print(r)

mejor = max(resumen, key=lambda x: x["promedio"])
print("\nMejor estudiante:", mejor)

# %% [markdown]
# ---
# ## 5. Ejercicios **para resolver SIN solución**
#
# > A continuación encontrarás problemas propuestos **sin respuestas**. Úsalos para evaluar tu comprensión.
#
# ### Ejercicio A: Objetos básicos y formato
# 1. Pide por teclado (o asume variables) `nombre`, `edad`, `estatura_m` y construye una cadena formateada con f-strings.
# 2. Calcula cuántos meses y días aproximados has vivido (edad * 12; edad * 365).
#
# > Escribe tu solución abajo:

# %%
# Tu solución aquí

# %% [markdown]
# ### Ejercicio B: Listas y slicing
# 1. Crea una lista con 8 productos (strings) y otra con sus precios (floats) del mismo tamaño.
# 2. Obtén los 5 productos más baratos usando slicing luego de ordenar **copias** de las listas (no mutar las originales).
# 3. Crea una lista de precios con descuento del 10% usando list comprehension (redondea a 2 decimales).

# %%
# Tu solución aquí

# %% [markdown]
# ### Ejercicio C: Diccionarios anidados
# Crea un diccionario `inventario` donde cada clave sea el nombre de un producto y el valor sea otro diccionario con:
# - `precio` (float)
# - `stock` (int)
# - `categoria` (str)
#
# Calcula el **valor total** del inventario y una lista con los productos de `categoria == "tecnología"`.

# %%
# Tu solución aquí

# %% [markdown]
# ### Ejercicio D: Conjuntos (sets) y duplicados
# Dada una lista de correos con duplicados y mayúsculas/minúsculas mezcladas, normaliza (minúsculas) y obtén el conjunto de correos únicos. Cuenta cuántos hay.

# %%
# Tu solución aquí

# %% [markdown]
# ### Ejercicio E: Funciones puras y reutilización
# 1. Escribe `def aplicar_iva(precio, tasa=0.19)` que devuelva el precio con IVA.
# 2. Escribe `def filtrar_caros(precios, umbral)` que devuelva precios mayores al umbral.
# 3. Combina ambas funciones para tomar una lista de precios, aplicar IVA y luego filtrar por `umbral = 1000`.

# %%
# Tu solución aquí

# %% [markdown]
# ### Ejercicio F: Mini‑proyecto
# Construye una función `resumen_ventas(ventas)` donde `ventas` es una lista de diccionarios del tipo:
# ```python
# { "producto": "A", "cantidad": 3, "precio_unit": 2500.0 }
# ```
# La función debe devolver:
# - **ingreso_total**
# - **producto_mas_vendido** (por cantidad)
# - **ticket_promedio** (ingreso_total / número de transacciones)

# %%
# Tu solución aquí
