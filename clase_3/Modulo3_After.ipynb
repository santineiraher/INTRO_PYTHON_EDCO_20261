# %% [markdown]
# # **Introducción al análisis de datos en Python**
# #### Profesor: Santiago Neira

# %% [markdown]
# ## Clase 3. Pandas
# Una de las habilidades más relevantes para un Data Analyst o un Data Scientist es el manejo de datos estructurados. En este tutorial aprenderá cómo importar archivos a Python para crear `DataFrames` y de esta forma manipularlos para que estos queden en el formato más conveniente para su análisis.

# %% [markdown]
# ## Introducción a Pandas

# %% [markdown]
# ###  ¿Qué es Pandas?
# Pandas es una librería de código abierto para Python que proporciona herramientas de análisis de datos de alto rendimiento y fáciles de usar. Está construida sobre la biblioteca NumPy y proporciona estructuras de datos de alto nivel para trabajar con datos estructurados y tabulares, como hojas de cálculo y bases de datos relacionales.
#
# Algunas de las características más importantes de Pandas son:
#
# - Ofrece estructuras de datos para trabajar con datos tabulares, como el DataFrame y la Serie.
# - Proporciona herramientas para la lectura y escritura de datos desde y hacia una variedad de formatos de archivo, como CSV, Excel, SQL, entre otros.
# - Permite realizar operaciones de limpieza y preprocesamiento de datos, como la eliminación de valores perdidos o la normalización de datos.
# - Ofrece una amplia variedad de métodos para el análisis de datos, como el agrupamiento, la agregación, la selección y el filtrado de datos.
# - Permite la visualización de datos con la integración con otras bibliotecas de Python, como Matplotlib.
#
# Pandas es ampliamente utilizado en ciencia de datos, finanzas, ingeniería y otras disciplinas que requieren la manipulación y el análisis de grandes conjuntos de datos. Es una de las herramientas más populares en Python para el análisis de datos debido a su facilidad de uso y su amplia gama de funciones.
#
# En el siguiente diagrama se puede ver la estructura general de un `dataframe`, es muy similar a un Excel pero solo con una hoja. En este caso las filas representan observaciones y las columnas representan variables.
#
# <center>
# <img src="img/dataframe.png" alt="dataframe" width="500" height="300">
# </center>

# %% [markdown]
# Comenzaremos nuestra introducción a `Pandas` creando nuestro primer `dataframe` con un diccionario.

# %%
# !pip3 install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\santiago neira\appdata\local\programs\python\python311\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\santiago neira\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\santiago neira\appdata\roaming\python\python311\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\santiago neira\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\santiago neira\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\santiago neira\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#%pip3 install pandas

# %%
import pandas as pd

# %%
# Cada variable de nuestro dataframe partirá de una lista
nombres = ["Jose", "Esteban", "Elena", "Ana", "Julian", "Juan"]
sexo = ["M", "M", "F", "F", "M", None]
edad = [24, 25, 32, 45, 52, 20]
peso = [75, 80, 60, 86, 72, 70]

# %%
# Creamos un diccionario con toda la información
un_diccionario = {
    "nombres": nombres,
    "sexo": sexo,
    "edad": edad,
    "peso": peso
}

# %%
un_diccionario
# Out:
# {'nombres': ['Jose', 'Esteban', 'Elena', 'Ana', 'Julian', 'Juan'],
#  'sexo': ['M', 'M', 'F', 'F', 'M', None],
#  'edad': [24, 25, 32, 45, 52, 20],
#  'peso': [75, 80, 60, 86, 72, 70]}

# %%
# Construimos nuestro primer dataframe
data = pd.DataFrame(un_diccionario)

# %%
# Visualizamos nuestro dataframe
data
# Out:
#    nombres  sexo  edad  peso
# 0     Jose     M    24    75
# 1  Esteban     M    25    80
# 2    Elena     F    32    60
# 3      Ana     F    45    86
# 4   Julian     M    52    72
# 5     Juan  None    20    70

# %% [markdown]
# El `dataframe` es un objeto en Python que tiene unos atributos especiales. Estos atributos nos sirven para estudiar las características de nuestro objeto. Los principales se listan a continuación:
#
# - `.index`: es una propiedad que devuelve una lista con los nombres de fila del dataframe.
#
# - `.columns`: es una propiedad que devuelve una lista con los nombres de las columnas del dataframe.
#
# - `.shape`: es una propiedad que devuelve una tupla que indica el número de filas y columnas en el dataframe. Por ejemplo, un dataframe con 100 filas y 5 columnas tendría una forma de (100, 5).
#
# - `.size`: es una propiedad que devuelve la cantidad de datos o celdas del dataframe. Por ejemplo, un dataframe con 100 filas y 5 columnas tendría un `size` de $100\times5=500$.
#
# - `.count()`: este método cuenta la cantidad de valores no nulos por columna o fila.
#
# - `.values`: es una propiedad que devuelve un array NumPy que contiene los valores del dataframe.
#
# - `.T`: es un atributo que devuelve la base traspuesta.
#
# - `.dtypes`: es una propiedad que devuelve un objeto que describe los tipos de datos de cada columna.
#
# - `.head(n)`: es un método que devuelve las primeras n filas del dataframe.
#
# - `.tail(n)`: es un método que devuelve las últimas n filas del dataframe.
#
# - `.info()`: es un método que muestra información sobre el dataframe, incluyendo su forma, los tipos de datos de cada columna y la cantidad de valores no nulos.
#
# - `.describe()`: es un método que muestra estadísticas descriptivas sobre el dataframe, incluyendo la media, la mediana, la desviación estándar, etc.
#
# A continuación estudiaremos a detalle cada uno de estos métodos y atributos.

# %%
data
# Out:
#    nombres  sexo  edad  peso
# 0     Jose     M    24    75
# 1  Esteban     M    25    80
# 2    Elena     F    32    60
# 3      Ana     F    45    86
# 4   Julian     M    52    72
# 5     Juan  None    20    70

# %%
# .index Estudiamos los nombres del índice
data.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
# .columns ¿Cuáles son los nombres de las columnas?
data.columns
# Out:
# Index(['nombres', 'sexo', 'edad', 'peso'], dtype='object')

# %%
# .shape ¿Cuáles son las dimensiones del dataframe?
data.shape
# Out:
# (6, 4)

# %%
# .size ¿Cuántos datos tengo?
data.size
# Out:
# 24

# %%
# .count() ¿Cuántos datos no nulos tengo por columna?
data.count()
# Out:
# nombres    6
# sexo       5
# edad       6
# peso       6
# dtype: int64

# %%
data
# Out:
#    nombres  sexo  edad  peso
# 0     Jose     M    24    75
# 1  Esteban     M    25    80
# 2    Elena     F    32    60
# 3      Ana     F    45    86
# 4   Julian     M    52    72
# 5     Juan  None    20    70

# %%
# .count() ¿Cuántos datos no nulos tengo por fila/observación/individuo?
data.count(axis = 1)
# Out:
# 0    4
# 1    4
# 2    4
# 3    4
# 4    4
# 5    3
# dtype: int64

# %%
# axis = 0 calcula las funciones por columna. Esta es la opción por default
# axis = 1 calcula las funciones por fila
data.count(axis = 0)
# Out:
# nombres    6
# sexo       5
# edad       6
# peso       6
# dtype: int64

# %%
# .values Convierte el dataframe en un np.array de dos dimensiones
data.values
# Out:
# array([['Jose', 'M', 24, 75],
#        ['Esteban', 'M', 25, 80],
#        ['Elena', 'F', 32, 60],
#        ['Ana', 'F', 45, 86],
#        ['Julian', 'M', 52, 72],
#        ['Juan', None, 20, 70]], dtype=object)

# %%
data
# Out:
#    nombres  sexo  edad  peso
# 0     Jose     M    24    75
# 1  Esteban     M    25    80
# 2    Elena     F    32    60
# 3      Ana     F    45    86
# 4   Julian     M    52    72
# 5     Juan  None    20    70

# %%
# .T Trasponer
data.T
# Out:
#             0        1      2    3       4     5
# nombres  Jose  Esteban  Elena  Ana  Julian  Juan
# sexo        M        M      F    F       M  None
# edad       24       25     32   45      52    20
# peso       75       80     60   86      72    70

# %%
data
# Out:
#    nombres  sexo  edad  peso
# 0     Jose     M    24    75
# 1  Esteban     M    25    80
# 2    Elena     F    32    60
# 3      Ana     F    45    86
# 4   Julian     M    52    72
# 5     Juan  None    20    70

# %%
data_transpuesta = data.T

# %%
data_transpuesta
# Out:
#             0        1      2    3       4     5
# nombres  Jose  Esteban  Elena  Ana  Julian  Juan
# sexo        M        M      F    F       M  None
# edad       24       25     32   45      52    20
# peso       75       80     60   86      72    70

# %%
data.T.index
# Out:
# Index(['nombres', 'sexo', 'edad', 'peso'], dtype='object')

# %%
data.T.columns
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
data
# Out:
#    nombres  sexo  edad  peso
# 0     Jose     M    24    75
# 1  Esteban     M    25    80
# 2    Elena     F    32    60
# 3      Ana     F    45    86
# 4   Julian     M    52    72
# 5     Juan  None    20    70

# %%
# .dtypes ¿Cuál es el tipo de cada variable?
data.dtypes
# Out:
# nombres    object
# sexo       object
# edad        int64
# peso        int64
# dtype: object

# %%
# .head() por defecto entrega las primeras 5 filas
data.head()
# Out:
#    nombres sexo  edad  peso
# 0     Jose    M    24    75
# 1  Esteban    M    25    80
# 2    Elena    F    32    60
# 3      Ana    F    45    86
# 4   Julian    M    52    72

# %%
# Primera fila
data.head(1)
# Out:
#   nombres sexo  edad  peso
# 0    Jose    M    24    75

# %%
# Primeras dos filas
data.head(2)
# Out:
#    nombres sexo  edad  peso
# 0     Jose    M    24    75
# 1  Esteban    M    25    80

# %%
# .tail() Por defecto devuelve las últimas 5 filas
data.tail()
# Out:
#    nombres  sexo  edad  peso
# 1  Esteban     M    25    80
# 2    Elena     F    32    60
# 3      Ana     F    45    86
# 4   Julian     M    52    72
# 5     Juan  None    20    70

# %%
# Última fila
data.tail(1)
# Out:
#   nombres  sexo  edad  peso
# 5    Juan  None    20    70

# %%
# Últimas dos filas
data.tail(2)
# Out:
#   nombres  sexo  edad  peso
# 4  Julian     M    52    72
# 5    Juan  None    20    70

# %%
# .info() descripción general de la estructura de la base
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   nombres  6 non-null      object
#  1   sexo     5 non-null      object
#  2   edad     6 non-null      int64
#  3   peso     6 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 324.0+ bytes

# %%
# .describe() Estadísticas descriptivas de la data
data.describe()
# Out:
#             edad       peso
# count   6.000000   6.000000
# mean   33.000000  73.833333
# std    12.806248   8.908797
# min    20.000000  60.000000
# 25%    24.250000  70.500000
# 50%    28.500000  73.500000
# 75%    41.750000  78.750000
# max    52.000000  86.000000

# %%
data
# Out:
#    nombres  sexo  edad  peso
# 0     Jose     M    24    75
# 1  Esteban     M    25    80
# 2    Elena     F    32    60
# 3      Ana     F    45    86
# 4   Julian     M    52    72
# 5     Juan  None    20    70

# %%
data.describe(include = "object")
# Out:
#        nombres sexo
# count        6    5
# unique       6    2
# top       Jose    M
# freq         1    3

# %%
data.describe(include = "all")
# Out:
#        nombres sexo       edad       peso
# count        6    5   6.000000   6.000000
# unique       6    2        NaN        NaN
# top       Jose    M        NaN        NaN
# freq         1    3        NaN        NaN
# mean       NaN  NaN  33.000000  73.833333
# std        NaN  NaN  12.806248   8.908797
# min        NaN  NaN  20.000000  60.000000
# 25%        NaN  NaN  24.250000  70.500000
# 50%        NaN  NaN  28.500000  73.500000
# 75%        NaN  NaN  41.750000  78.750000
# max        NaN  NaN  52.000000  86.000000

# %% [markdown]
# ### Indexación y ejes
# Adicionalmente, para manipular los dataframes es importante aprender como extraer fracciones de nuestra información. A esto se le conoce generalmente como *slicing*. En esta sección aprenderemos a filtrar la data por columnas y por filas. Los métodos que veremos serán.
#
# - `[{nombre de la columna}]` y `.{nombre de la columna}`: Extracción de columnas.
#
# - `set_index()`: Convertir una columna como índice.
#
# - `.loc[]`: es un método para acceder a filas y columnas del dataframe por etiquetas de fila y columna.
#
# - `.iloc[]`: es un método para acceder a filas y columnas del dataframe por índice entero.
#
# - `.groupby()`: es un método para agrupar los datos por una o más columnas y realizar cálculos sobre los grupos resultantes.
#
# - `.reset_index()`: Reiniciar el índice para que sea una enumeración de las filas.
#
# - `.sort_values()`: Re-ordenar las filas.
#
# - `.rename()`: Cambiarle el nombre a una fila o una columna.
#
# - `.unique()`: Devuelve los valores únicos de la columna.
#
# - `.value_counts()`: Cuenta la cantidad de valores únicos por columna.

# %% [markdown]
# **Extraer columnas**
#
# Para extraer columnas tenemos dos métodos.
# 1. El primero consiste escribir entre corchetes cuadrados (`[]`) el nombre de la columna que se desea extraer entre comillas. Este método también permite extraer más de una columnas. Si ese es el caso, se pondría entre los corchetes cuadrados una lista con los nombres de las columnas deseadas entre comillas y separadas por comas.
# 2. El segundo método consiste en poner el nombre de la columna que se quiere extraer después de un punto `.`. Este método solo sirve si el nombre no está separado por espacios o caracteres especiales.

# %%
data
# Out:
#    nombres  sexo  edad  peso
# 0     Jose     M    24    75
# 1  Esteban     M    25    80
# 2    Elena     F    32    60
# 3      Ana     F    45    86
# 4   Julian     M    52    72
# 5     Juan  None    20    70

# %%
# Método 1
data["nombres"]
# Out:
# 0       Jose
# 1    Esteban
# 2      Elena
# 3        Ana
# 4     Julian
# 5       Juan
# Name: nombres, dtype: object

# %%
# Método 1
data[["nombres", "peso"]]
# Out:
#    nombres  peso
# 0     Jose    75
# 1  Esteban    80
# 2    Elena    60
# 3      Ana    86
# 4   Julian    72
# 5     Juan    70

# %%
columnas_deseadas = ['nombres', "peso"]
data[columnas_deseadas]
# Out:
#    nombres  peso
# 0     Jose    75
# 1  Esteban    80
# 2    Elena    60
# 3      Ana    86
# 4   Julian    72
# 5     Juan    70

# %%
# Método 2
data.nombres
# Out:
# 0       Jose
# 1    Esteban
# 2      Elena
# 3        Ana
# 4     Julian
# 5       Juan
# Name: nombres, dtype: object

# %%
data.columns
# Out:
# Index(['nombres', 'sexo', 'edad', 'peso'], dtype='object')

# %%
data.sexo
# Out:
# 0       M
# 1       M
# 2       F
# 3       F
# 4       M
# 5    None
# Name: sexo, dtype: object

# %%
data
# Out:
#    nombres  sexo  edad  peso
# 0     Jose     M    24    75
# 1  Esteban     M    25    80
# 2    Elena     F    32    60
# 3      Ana     F    45    86
# 4   Julian     M    52    72
# 5     Juan  None    20    70

# %%
# Convertir una columna como un índice
data_con_indice_nombre = data.set_index('nombres')

# %%
data_con_indice_nombre
# Out:
#          sexo  edad  peso
# nombres
# Jose        M    24    75
# Esteban     M    25    80
# Elena       F    32    60
# Ana         F    45    86
# Julian      M    52    72
# Juan     None    20    70

# %%
data_con_indice_nombre.index
# Out:
# Index(['Jose', 'Esteban', 'Elena', 'Ana', 'Julian', 'Juan'], dtype='object', name='nombres')

# %%
data.set_index('nombres')
# Out:
#          sexo  edad  peso
# nombres
# Jose        M    24    75
# Esteban     M    25    80
# Elena       F    32    60
# Ana         F    45    86
# Julian      M    52    72
# Juan     None    20    70

# %%
data['peso']
# Out:
# 0    75
# 1    80
# 2    60
# 3    86
# 4    72
# 5    70
# Name: peso, dtype: int64

# %%
# Si no sobreescribimos el objeto, no se guardan los cambios
data = data.set_index('nombres')
data
# Out:
#          sexo  edad  peso
# nombres
# Jose        M    24    75
# Esteban     M    25    80
# Elena       F    32    60
# Ana         F    45    86
# Julian      M    52    72
# Juan     None    20    70

# %%
# Otra forma de sobreescribir el objeto sin necesidad de asignarlo es usando el argumento inplace = True, dentro
# de las funciones de Pandas
data.set_index("sexo", append = True, inplace = True)
data
# Out:
#               edad  peso
# nombres sexo
# Jose    M       24    75
# Esteban M       25    80
# Elena   F       32    60
# Ana     F       45    86
# Julian  M       52    72
# Juan    NaN     20    70

# %%
# Para resetar el índice usamos .reset_index()
data.reset_index(inplace = True)
data
# Out:
#    nombres sexo  edad  peso
# 0     Jose    M    24    75
# 1  Esteban    M    25    80
# 2    Elena    F    32    60
# 3      Ana    F    45    86
# 4   Julian    M    52    72
# 5     Juan  NaN    20    70

# %%
data
# Out:
#    nombres sexo  edad  peso
# 0     Jose    M    24    75
# 1  Esteban    M    25    80
# 2    Elena    F    32    60
# 3      Ana    F    45    86
# 4   Julian    M    52    72
# 5     Juan  NaN    20    70

# %%
# Vuelva nombres el índice
data.set_index("nombres", inplace = True)

# %%
data
# Out:
#         sexo  edad  peso
# nombres
# Jose       M    24    75
# Esteban    M    25    80
# Elena      F    32    60
# Ana        F    45    86
# Julian     M    52    72
# Juan     NaN    20    70

# %%
# Ordene por edad de menor a mayor. No guarde el valor
data.sort_values(['peso','edad'])
# Out:
#         sexo  edad  peso
# nombres
# Elena      F    32    60
# Juan     NaN    20    70
# Julian     M    52    72
# Jose       M    24    75
# Esteban    M    25    80
# Ana        F    45    86

# %%
# Ordene por edad de mayor a menor. No guarde el valor
data.sort_values('edad', ascending = False)

# Note que los índices se movieron!
# Out:
#         sexo  edad  peso
# nombres
# Julian     M    52    72
# Ana        F    45    86
# Elena      F    32    60
# Esteban    M    25    80
# Jose       M    24    75
# Juan     NaN    20    70

# %%
# Cambie el nombre de la columna sexo a género
data.rename(columns = {"sexo": "género"})
# Out:
#         género  edad  peso
# nombres
# Jose         M    24    75
# Esteban      M    25    80
# Elena        F    32    60
# Ana          F    45    86
# Julian       M    52    72
# Juan       NaN    20    70

# %%
data_renombrada= data.rename(columns = {"sexo": "género", "peso":"peso (Kg)"
                                        })

# %%
data_renombrada
# Out:
#         género  edad  peso (Kg)
# nombres
# Jose         M    24         75
# Esteban      M    25         80
# Elena        F    32         60
# Ana          F    45         86
# Julian       M    52         72
# Juan       NaN    20         70

# %%
data
# Out:
#         sexo  edad  peso
# nombres
# Jose       M    24    75
# Esteban    M    25    80
# Elena      F    32    60
# Ana        F    45    86
# Julian     M    52    72
# Juan     NaN    20    70

# %%
data["sexo"].unique() ### MUY útil para conocer las categorías de una variable
# Out:
# array(['M', 'F', nan], dtype=object)

# %%
# Valores únicos de la columna sexo
data.sexo.unique()
# Out:
# array(['M', 'F', nan], dtype=object)

# %%
len(data.edad.unique())
# Out:
# 6

# %%
data.edad.nunique()
# Out:
# 6

# %%
# ¿Cuántos hombres y mujeres tenemos?
data["sexo"].value_counts(dropna=False)
# Out:
# sexo
# M      3
# F      2
# NaN    1
# Name: count, dtype: int64

# %%
data['edad'].value_counts()
# Out:
# edad
# 24    1
# 25    1
# 32    1
# 45    1
# 52    1
# 20    1
# Name: count, dtype: int64

# %%
# Incluya los valores faltantes en el conteo
#dropna: drop nan - eliminar los valores nulos
data["sexo"].value_counts(dropna = False)
# Out:
# sexo
# M      3
# F      2
# NaN    1
# Name: count, dtype: int64

# %%
data
# Out:
#         sexo  edad  peso
# nombres
# Jose       M    24    75
# Esteban    M    25    80
# Elena      F    32    60
# Ana        F    45    86
# Julian     M    52    72
# Juan     NaN    20    70

# %%
data["sexo"].value_counts(normalize = True)
# Out:
# sexo
# M    0.6
# F    0.4
# Name: proportion, dtype: float64

# %%
# ¿Cuál es la proporción de hombres y mujeres tenemos?
data["sexo"].value_counts(normalize = True,dropna = False)
# Out:
# sexo
# M      0.500000
# F      0.333333
# NaN    0.166667
# Name: proportion, dtype: float64

# %% [markdown]
# Los métodos `.iloc` y ``.loc`` son utilizados en Pandas para acceder a los datos de un dataframe de diferentes maneras.
#
# `.iloc` se utiliza para acceder a los datos del dataframe mediante índices enteros. Permite seleccionar filas y columnas utilizando números enteros en lugar de etiquetas de fila y columna. La sintaxis general para utilizar `.iloc` es la siguiente:
#
# ```python
# dataframe.iloc[filas, columnas]
# ```
#
# Donde `filas` y `columnas` son listas o arrays de números enteros que indican las filas y columnas que se desean seleccionar, respectivamente.
#
# <center>
# <div>
# <img src="img/iloc2.png" width="500"/>
# </div>
# </center>
#
# Por ejemplo, para seleccionar las primeras 3 filas y las primeras 2 columnas de un dataframe, se puede utilizar el siguiente código:
#
# ```python
# dataframe.iloc[:3, :2]
# ```
#
# Recuerde que la indexación en python empieza en 0. A continuación puede encontrar una referencia gráfica:
# <center>
# <img src="img/iloc1.png" alt="indexación" width="450" height="200">
# </center>
#
# Por otro lado, `.loc` se utiliza para acceder a los datos del dataframe mediante etiquetas de fila y columna. Permite seleccionar filas y columnas utilizando las etiquetas de fila y columna en lugar de índices enteros. La sintaxis general para utilizar `.loc` es la siguiente:
#
# ```python
# dataframe.loc[filas, columnas]
# ```
#
# Donde `filas` y `columnas` son listas o arrays de etiquetas de fila y columna que indican las filas y columnas que se desean seleccionar, respectivamente.
#
# <center>
# <div>
# <img src="img/iloc3.png" width="500"/>
# </div>
# </center>
#
# Por ejemplo, para seleccionar todas las filas donde la columna "edad" es mayor o igual a 30, se puede utilizar el siguiente código:
#
# ```python
# dataframe.loc[dataframe['edad'] >= 30, :]
# ```
#
# En resumen, `.iloc` se utiliza para acceder a los datos mediante índices enteros, mientras que `.loc` se utiliza para acceder a los datos mediante etiquetas de fila y columna. Ambos métodos son muy útiles para la selección y manipulación de datos en Pandas.

# %%
data
# Out:
#         sexo  edad  peso
# nombres
# Jose       M    24    75
# Esteban    M    25    80
# Elena      F    32    60
# Ana        F    45    86
# Julian     M    52    72
# Juan     NaN    20    70

# %%
data.columns
# Out:
# Index(['sexo', 'edad', 'peso'], dtype='object')

# %%
data.iloc[1,1]
# Out:
# np.int64(25)

# %%
data.iloc[:4,1:]
# Out:
#          edad  peso
# nombres
# Jose       24    75
# Esteban    25    80
# Elena      32    60
# Ana        45    86

# %%
data
# Out:
#         sexo  edad  peso
# nombres
# Jose       M    24    75
# Esteban    M    25    80
# Elena      F    32    60
# Ana        F    45    86
# Julian     M    52    72
# Juan     NaN    20    70

# %%
# Extraiga la fila de Ana usando .loc
data.loc['Ana',['edad','sexo']]
# Out:
# edad    45
# sexo     F
# Name: Ana, dtype: object

# %%
## Qué persona tiene 45 años?
data.loc[data.edad == 45]
# Out:
#         sexo  edad  peso
# nombres
# Ana        F    45    86

# %%
data
# Out:
#         sexo  edad  peso
# nombres
# Jose       M    24    75
# Esteban    M    25    80
# Elena      F    32    60
# Ana        F    45    86
# Julian     M    52    72
# Juan     NaN    20    70

# %%
data.loc[data.sexo=='F']
# Out:
#         sexo  edad  peso
# nombres
# Elena      F    32    60
# Ana        F    45    86

# %%
data_filtrada=data.loc[data.edad>30]
data_filtrada[['sexo','peso']]
# Out:
#         sexo  peso
# nombres
# Elena      F    60
# Ana        F    86
# Julian     M    72

# %%
data.loc[(data.edad>25)&(data.sexo=='F')]
# Out:
#         sexo  edad  peso
# nombres
# Elena      F    32    60
# Ana        F    45    86

# %%
data
# Out:
#         sexo  edad  peso
# nombres
# Jose       M    24    75
# Esteban    M    25    80
# Elena      F    32    60
# Ana        F    45    86
# Julian     M    52    72
# Juan     NaN    20    70

# %%
data.loc[data.sexo == "F"]
# Out:
#         sexo  edad  peso
# nombres
# Elena      F    32    60
# Ana        F    45    86

# %%
data.loc[data.peso > 50]
# Out:
#         sexo  edad  peso
# nombres
# Jose       M    24    75
# Esteban    M    25    80
# Elena      F    32    60
# Ana        F    45    86
# Julian     M    52    72
# Juan     NaN    20    70

# %%
data
# Out:
#         sexo  edad  peso
# nombres
# Jose       M    24    75
# Esteban    M    25    80
# Elena      F    32    60
# Ana        F    45    86
# Julian     M    52    72
# Juan     NaN    20    70

# %%
data.loc[data.sexo=='M',:]
# Out:
#         sexo  edad  peso
# nombres
# Jose       M    24    75
# Esteban    M    25    80
# Julian     M    52    72

# %%
data.loc[data.sexo=='M',:].describe()
# Out:
#             edad       peso
# count   3.000000   3.000000
# mean   33.666667  75.666667
# std    15.885003   4.041452
# min    24.000000  72.000000
# 25%    24.500000  73.500000
# 50%    25.000000  75.000000
# 75%    38.500000  77.500000
# max    52.000000  80.000000

# %%
data.loc[data.sexo=='M'].sort_values('peso')
# Out:
#         sexo  edad  peso
# nombres
# Julian     M    52    72
# Jose       M    24    75
# Esteban    M    25    80

# %%
data_filtrada = data.loc[data.sexo=='M']
data_filtrada.sort_values('peso')
# Out:
#         sexo  edad  peso
# nombres
# Julian     M    52    72
# Jose       M    24    75
# Esteban    M    25    80

# %%
datos_transpuesto = data.T

# %%
datos_transpuesto
# Out:
# nombres Jose Esteban Elena Ana Julian Juan
# sexo       M       M     F   F      M  NaN
# edad      24      25    32  45     52   20
# peso      75      80    60  86     72   70

# %%
datos_transpuesto['Gelver'] = ['M',32,78]

# %%
datos_transpuesto
# Out:
# nombres Jose Esteban Elena Ana Julian Juan Gelver
# sexo       M       M     F   F      M  NaN      M
# edad      24      25    32  45     52   20     32
# peso      75      80    60  86     72   70     78

# %%
datos_transpuesto.loc[:, 'Gelver']
# Out:
# sexo     M
# edad    32
# peso    78
# Name: Gelver, dtype: object

# %%
data
# Out:
#         sexo  edad  peso
# nombres
# Jose       M    24    75
# Esteban    M    25    80
# Elena      F    32    60
# Ana        F    45    86
# Julian     M    52    72
# Juan     NaN    20    70

# %%
# Extraiga la columna de edad usando .loc
data.loc[:,'edad']
# Out:
# nombres
# Jose       24
# Esteban    25
# Elena      32
# Ana        45
# Julian     52
# Juan       20
# Name: edad, dtype: int64

# %%
# Extraiga los pesos de Juan y Esteban usando .loc
data.loc[['Juan', 'Esteban'], ['peso','edad']]
# Out:
#          peso  edad
# nombres
# Juan       70    20
# Esteban    80    25

# %%
data
# Out:
#         sexo  edad  peso
# nombres
# Jose       M    24    75
# Esteban    M    25    80
# Elena      F    32    60
# Ana        F    45    86
# Julian     M    52    72
# Juan     NaN    20    70

# %%
data['edad']>30
# Out:
# nombres
# Jose       False
# Esteban    False
# Elena       True
# Ana         True
# Julian      True
# Juan       False
# Name: edad, dtype: bool

# %%
data.loc[data['edad']>30,:]
# Out:
#         sexo  edad  peso
# nombres
# Elena      F    32    60
# Ana        F    45    86
# Julian     M    52    72

# %%
data.loc[data['peso']>70]
# Out:
#         sexo  edad  peso
# nombres
# Jose       M    24    75
# Esteban    M    25    80
# Ana        F    45    86
# Julian     M    52    72

# %%
data.loc[(data['edad'] > 30) & (data['sexo'] == 'M')]
# Out:
#         sexo  edad  peso
# nombres
# Julian     M    52    72

# %%
# Extraiga a todas las personas de sexo masculino mayores a 30 años
data.loc[(data['edad'] > 30) | (data['sexo'] == 'M'),:]
# Out:
#         sexo  edad  peso
# nombres
# Jose       M    24    75
# Esteban    M    25    80
# Elena      F    32    60
# Ana        F    45    86
# Julian     M    52    72

# %%
data.loc[(data['edad'] > 30) & (data['sexo'] == 'M')]
# Out:
#         sexo  edad  peso
# nombres
# Julian     M    52    72

# %%
data
# Out:
#         sexo  edad  peso
# nombres
# Jose       M    24    75
# Esteban    M    25    80
# Elena      F    32    60
# Ana        F    45    86
# Julian     M    52    72
# Juan     NaN    20    70

# %%
# Extraiga la segunda fila usando .iloc
data.iloc[1]
# Out:
# sexo     M
# edad    25
# peso    80
# Name: Esteban, dtype: object

# %%
data.iloc[1,]
# Out:
# sexo     M
# edad    25
# peso    80
# Name: Esteban, dtype: object

# %%
# Extraiga la segunda y tercera columna usando .iloc
data.iloc[:,[1,2]]
# Out:
#          edad  peso
# nombres
# Jose       24    75
# Esteban    25    80
# Elena      32    60
# Ana        45    86
# Julian     52    72
# Juan       20    70

# %%
# Extraiga la primera y última fila y segunda columna usando .iloc
data.iloc[[0,-1],[1]]
# Out:
#          edad
# nombres
# Jose       24
# Juan       20

# %%
data
# Out:
#         sexo  edad  peso
# nombres
# Jose       M    24    75
# Esteban    M    25    80
# Elena      F    32    60
# Ana        F    45    86
# Julian     M    52    72
# Juan     NaN    20    70

# %%
data.iloc[-1,-1]
# Out:
# np.int64(70)

# %%
# Reinicie el índice
data.reset_index(inplace = True, drop = False) 
data
# Out:
#    nombres sexo  edad  peso
# 0     Jose    M    24    75
# 1  Esteban    M    25    80
# 2    Elena    F    32    60
# 3      Ana    F    45    86
# 4   Julian    M    52    72
# 5     Juan  NaN    20    70

# %%
data_ana=data.loc[data['nombres']=='Ana']
data_ana[['sexo', 'peso']]
# Out:
#   sexo  peso
# 3    F    86

# %%
data.loc[data.nombres=='Ana', ['sexo', 'peso']]
# Out:
#   sexo  peso
# 3    F    86

# %% [markdown]
# ## Pandas intermedio

# %% [markdown]
# ### Modificación de valores
# Las columnas dentro de un dataframe a su vez son un objeto. Estos se conocen como `Series` y son una estructura de datos unidimensional que contiene una secuencia de valores y una etiqueta de índice para cada uno de ellos. Se puede pensar en una serie como una columna en una hoja de cálculo o como un array unidimensional con etiquetas de índice.
#
# Una serie de Pandas se puede crear a partir de una lista, un array NumPy, un diccionario o incluso otro objeto de serie. La etiqueta de índice por defecto para cada elemento de la serie es simplemente un rango de números enteros de 0 a n-1, donde n es el número de elementos en la serie. Sin embargo, se puede especificar etiquetas de índice personalizadas para cada elemento de la serie.

# %%
type(data["nombres"])
# Out:
# pandas.core.series.Series

# %%
data
# Out:
#    nombres sexo  edad  peso
# 0     Jose    M    24    75
# 1  Esteban    M    25    80
# 2    Elena    F    32    60
# 3      Ana    F    45    86
# 4   Julian    M    52    72
# 5     Juan  NaN    20    70

# %% [markdown]
# Podemos comenzar editando valores o celdas particulares. Por ejemplo, el sexooo de Juan está como nulo. Vamos a definirlo como masculino

# %%
data.loc[data.nombres == "Juan", "sexo"]
# Out:
# 5    NaN
# Name: sexo, dtype: object

# %%
data.loc[data.nombres == "Juan", "sexo"] = "M"

# %%
data
# Out:
#    nombres sexo  edad  peso
# 0     Jose    M    24    75
# 1  Esteban    M    25    80
# 2    Elena    F    32    60
# 3      Ana    F    45    86
# 4   Julian    M    52    72
# 5     Juan    M    20    70

# %% [markdown]
# Del mismo modo, también podemos editar columnas. Actualmente tenemos la edad en años, pasemosla a días.

# %%
data["edad"]*365
# Out:
# 0     8760
# 1     9125
# 2    11680
# 3    16425
# 4    18980
# 5     7300
# Name: edad, dtype: int64

# %%
data
# Out:
#    nombres sexo  edad  peso
# 0     Jose    M    24    75
# 1  Esteban    M    25    80
# 2    Elena    F    32    60
# 3      Ana    F    45    86
# 4   Julian    M    52    72
# 5     Juan    M    20    70

# %%
data["edad"] = data["edad"]*365

# %%
data
# Out:
#    nombres sexo   edad  peso
# 0     Jose    M   8760    75
# 1  Esteban    M   9125    80
# 2    Elena    F  11680    60
# 3      Ana    F  16425    86
# 4   Julian    M  18980    72
# 5     Juan    M   7300    70

# %% [markdown]
# También podemos crear una nueva variable

# %%
import numpy as np

# %%
data["nueva_variable"] = [1,2,3,np.nan,np.nan,np.nan]

# %%
data
# Out:
#    nombres sexo   edad  peso  nueva_variable
# 0     Jose    M   8760    75             1.0
# 1  Esteban    M   9125    80             2.0
# 2    Elena    F  11680    60             3.0
# 3      Ana    F  16425    86             NaN
# 4   Julian    M  18980    72             NaN
# 5     Juan    M   7300    70             NaN

# %%
data_renombrada = data.rename(columns={'edad':'edad(dias)'})
data_renombrada
# Out:
#    nombres sexo  edad(dias)  peso  nueva_variable
# 0     Jose    M        8760    75             1.0
# 1  Esteban    M        9125    80             2.0
# 2    Elena    F       11680    60             3.0
# 3      Ana    F       16425    86             NaN
# 4   Julian    M       18980    72             NaN
# 5     Juan    M        7300    70             NaN

# %% [markdown]
# Otro método para crear una nueva variable es usando el método `.assign()`

# %%
data = data.assign(nueva_variable2 = np.nan)
data
# Out:
#    nombres sexo   edad  peso  nueva_variable  nueva_variable2
# 0     Jose    M   8760    75             1.0              NaN
# 1  Esteban    M   9125    80             2.0              NaN
# 2    Elena    F  11680    60             3.0              NaN
# 3      Ana    F  16425    86             NaN              NaN
# 4   Julian    M  18980    72             NaN              NaN
# 5     Juan    M   7300    70             NaN              NaN

# %%
data['edad'] = data['edad']/365

data['edad_dias'] = data['edad']*365

# %%
data
# Out:
#    nombres sexo  edad  peso  nueva_variable  nueva_variable2  edad_dias
# 0     Jose    M  24.0    75             1.0              NaN     8760.0
# 1  Esteban    M  25.0    80             2.0              NaN     9125.0
# 2    Elena    F  32.0    60             3.0              NaN    11680.0
# 3      Ana    F  45.0    86             NaN              NaN    16425.0
# 4   Julian    M  52.0    72             NaN              NaN    18980.0
# 5     Juan    M  20.0    70             NaN              NaN     7300.0

# %%
data.loc[data.edad<=24,'nueva_variable'] = 'Rango 1: 18-24'
# Out:
# C:\Users\Santiago Neira\AppData\Local\Temp\ipykernel_33372\4244016696.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Rango 1: 18-24' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   data.loc[data.edad<=24,'nueva_variable'] = 'Rango 1: 18-24'

# %%
data
# Out:
#    nombres sexo  edad  peso  nueva_variable  nueva_variable2  edad_dias
# 0     Jose    M  24.0    75  Rango 1: 18-24              NaN     8760.0
# 1  Esteban    M  25.0    80             2.0              NaN     9125.0
# 2    Elena    F  32.0    60             3.0              NaN    11680.0
# 3      Ana    F  45.0    86             NaN              NaN    16425.0
# 4   Julian    M  52.0    72             NaN              NaN    18980.0
# 5     Juan    M  20.0    70  Rango 1: 18-24              NaN     7300.0

# %%
data.loc[data.edad<=24,'nueva_variable'] = 'Rango 1: 18-24'
data.loc[(data.edad>=25) & (data.edad<=32),'nueva_variable'] = 'Rango 2: 25-32'
data.loc[(data.edad>=33) & (data.edad<=54),'nueva_variable'] = 'Rango 3: 33-54'
data.loc[(data.edad>=55),'nueva_variable'] = 'Rango 4: 55+'
data
# Out:
#    nombres sexo  edad  peso  nueva_variable  nueva_variable2  edad_dias
# 0     Jose    M  24.0    75  Rango 1: 18-24              NaN     8760.0
# 1  Esteban    M  25.0    80  Rango 2: 25-32              NaN     9125.0
# 2    Elena    F  32.0    60  Rango 2: 25-32              NaN    11680.0
# 3      Ana    F  45.0    86  Rango 3: 33-54              NaN    16425.0
# 4   Julian    M  52.0    72  Rango 3: 33-54              NaN    18980.0
# 5     Juan    M  20.0    70  Rango 1: 18-24              NaN     7300.0

# %% [markdown]
# El valor con el que se modifica cada variable no tiene que ser el mismo para todas.

# %%
apellido = ["Urrutia", "Carvajal", "Gómez", "Tobón", "Pardo", "Lopez"]

# %%
data["nombres"] = data["nombres"] + " " + apellido

# %%
data
# Out:
#             nombres sexo  edad  peso  nueva_variable  nueva_variable2  \
# 0      Jose Urrutia    M  24.0    75  Rango 1: 18-24              NaN
# 1  Esteban Carvajal    M  25.0    80  Rango 2: 25-32              NaN
# 2       Elena Gómez    F  32.0    60  Rango 2: 25-32              NaN
# 3         Ana Tobón    F  45.0    86  Rango 3: 33-54              NaN
# 4      Julian Pardo    M  52.0    72  Rango 3: 33-54              NaN
# 5        Juan Lopez    M  20.0    70  Rango 1: 18-24              NaN
#
#    edad_dias
# 0     8760.0
# 1     9125.0
# 2    11680.0
# 3    16425.0
# 4    18980.0
# 5     7300.0

# %% [markdown]
# ### Estadísticas descriptivas
# Anteriormente pudimos ver como el método `.describe()` me daba un resumen de toda la base. Sin embargo, en esta sección veremos cada una de las principales funciones para sacar las estadísticas

# %%
data.describe()
# Out:
#             edad       peso  nueva_variable2     edad_dias
# count   6.000000   6.000000              0.0      6.000000
# mean   33.000000  73.833333              NaN  12045.000000
# std    12.806248   8.908797              NaN   4674.280693
# min    20.000000  60.000000              NaN   7300.000000
# 25%    24.250000  70.500000              NaN   8851.250000
# 50%    28.500000  73.500000              NaN  10402.500000
# 75%    41.750000  78.750000              NaN  15238.750000
# max    52.000000  86.000000              NaN  18980.000000

# %%
data.sum()
# Out:
# nombres            Jose UrrutiaEsteban CarvajalElena GómezAna Tob...
# sexo                                                          MMFFMM
# edad                                                           198.0
# peso                                                             443
# nueva_variable     Rango 1: 18-24Rango 2: 25-32Rango 2: 25-32Rang...
# nueva_variable2                                                  0.0
# edad_dias                                                    72270.0
# dtype: object

# %%
# Suma de todas las columnas
data.sum(axis=0)
# Out:
# nombres            Jose UrrutiaEsteban CarvajalElena GómezAna Tob...
# sexo                                                          MMFFMM
# edad                                                           198.0
# peso                                                             443
# nueva_variable     Rango 1: 18-24Rango 2: 25-32Rango 2: 25-32Rang...
# nueva_variable2                                                  0.0
# edad_dias                                                    72270.0
# dtype: object

# %%
data
# Out:
#             nombres sexo  edad  peso  nueva_variable  nueva_variable2  \
# 0      Jose Urrutia    M  24.0    75  Rango 1: 18-24              NaN
# 1  Esteban Carvajal    M  25.0    80  Rango 2: 25-32              NaN
# 2       Elena Gómez    F  32.0    60  Rango 2: 25-32              NaN
# 3         Ana Tobón    F  45.0    86  Rango 3: 33-54              NaN
# 4      Julian Pardo    M  52.0    72  Rango 3: 33-54              NaN
# 5        Juan Lopez    M  20.0    70  Rango 1: 18-24              NaN
#
#    edad_dias
# 0     8760.0
# 1     9125.0
# 2    11680.0
# 3    16425.0
# 4    18980.0
# 5     7300.0

# %%
data.sum(axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[143], line 1
# ----> 1 data.sum(axis=1)
#
# File c:\Users\Santiago Neira\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:11697, in DataFrame.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   11688 @doc(make_doc("sum", ndim=2))
#   11689 def sum(
#   11690     self,
#    (...)  11695     **kwargs,
#   11696 ):
# > 11697     result = super().sum(axis, skipna, numeric_only, min_count, **kwargs)
#   11698     return result.__finalize__(self, method="sum")
#
# File c:\Users\Santiago Neira\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:12571, in NDFrame.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   12563 def sum(
#   12564     self,
#   12565     axis: Axis | None = 0,
#    (...)  12569     **kwargs,
#   12570 ):
# > 12571     return self._min_count_stat_function(
#   12572         "sum", nanops.nansum, axis, skipna, numeric_only, min_count, **kwargs
#   12573     )
#
# File c:\Users\Santiago Neira\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:12554, in NDFrame._min_count_stat_function(self, name, func, axis, skipna, numeric_only, min_count, **kwargs)
#   12551 elif axis is lib.no_default:
#   12552     axis = 0
# > 12554 return self._reduce(
#   12555     func,
#   12556     name=name,
#   12557     axis=axis,
#   12558     skipna=skipna,
#   12559     numeric_only=numeric_only,
#   12560     min_count=min_count,
#   12561 )
#
# File c:\Users\Santiago Neira\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:11589, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   11585     df = df.T
#   11587 # After possibly _get_data and transposing, we are now in the
#   11588 #  simple case where we can use BlockManager.reduce
# > 11589 res = df._mgr.reduce(blk_func)
#   11590 out = df._constructor_from_mgr(res, axes=res.axes).iloc[0]
#   11591 if out_dtype is not None and out.dtype != "boolean":
#
# File c:\Users\Santiago Neira\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:1519, in BlockManager.reduce(self, func)
#    1517 res_blocks: list[Block] = []
#    1518 for blk in self.blocks:
# -> 1519     nbs = blk.reduce(func)
#    1520     res_blocks.extend(nbs)
#    1522 index = Index([None])  # placeholder
#
# File c:\Users\Santiago Neira\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\blocks.py:406, in Block.reduce(self, func)
#     400 @final
#     401 def reduce(self, func) -> list[Block]:
#     402     # We will apply the function and reshape the result into a single-row
#     403     #  Block with the same mgr_locs; squeezing will be done at a higher level
#     404     assert self.ndim == 2
# --> 406     result = func(self.values)
#     408     if self.values.ndim == 1:
#     409         res_values = result
#
# File c:\Users\Santiago Neira\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:11508, in DataFrame._reduce.<locals>.blk_func(values, axis)
#   11506         return np.array([result])
#   11507 else:
# > 11508     return op(values, axis=axis, skipna=skipna, **kwds)
#
# File c:\Users\Santiago Neira\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\nanops.py:85, in disallow.__call__.<locals>._f(*args, **kwargs)
#      81     raise TypeError(
#      82         f"reduction operation '{f_name}' not allowed for this dtype"
#      83     )
#      84 try:
# ---> 85     return f(*args, **kwargs)
#      86 except ValueError as e:
#      87     # we want to transform an object array
#      88     # ValueError message to the more typical TypeError
#      89     # e.g. this is normally a disallowed function on
#      90     # object arrays that contain strings
#      91     if is_object_dtype(args[0]):
#
# File c:\Users\Santiago Neira\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     401 if datetimelike and mask is None:
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#     407     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File c:\Users\Santiago Neira\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\nanops.py:477, in maybe_operate_rowwise.<locals>.newfunc(values, axis, **kwargs)
#     474         results = [func(x, **kwargs) for x in arrs]
#     475     return np.array(results)
# --> 477 return func(values, axis=axis, **kwargs)
#
# File c:\Users\Santiago Neira\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\nanops.py:646, in nansum(values, axis, skipna, min_count, mask)
#     643 elif dtype.kind == "m":
#     644     dtype_sum = np.dtype(np.float64)
# --> 646 the_sum = values.sum(axis, dtype=dtype_sum)
#     647 the_sum = _maybe_null_out(the_sum, axis, mask, values.shape, min_count=min_count)
#     649 return the_sum
#
# File c:\Users\Santiago Neira\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\_core\_methods.py:51, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      49 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      50          initial=_NoValue, where=True):
# ---> 51     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# TypeError: can only concatenate str (not "float") to str

# %%
data
# Out:
#             nombres sexo  edad  peso  nueva_variable  nueva_variable2  \
# 0      Jose Urrutia    M  24.0    75  Rango 1: 18-24              NaN
# 1  Esteban Carvajal    M  25.0    80  Rango 2: 25-32              NaN
# 2       Elena Gómez    F  32.0    60  Rango 2: 25-32              NaN
# 3         Ana Tobón    F  45.0    86  Rango 3: 33-54              NaN
# 4      Julian Pardo    M  52.0    72  Rango 3: 33-54              NaN
# 5        Juan Lopez    M  20.0    70  Rango 1: 18-24              NaN
#
#    edad_dias
# 0     8760.0
# 1     9125.0
# 2    11680.0
# 3    16425.0
# 4    18980.0
# 5     7300.0

# %%
# Suma por fila
data.sum(axis = 1, numeric_only = True)
# Out:
# 0     8859.0
# 1     9230.0
# 2    11772.0
# 3    16556.0
# 4    19104.0
# 5     7390.0
# dtype: float64

# %%
# Suma de toda la columna peso
data["peso"].sum()
# Out:
# np.int64(443)

# %%
# Dato mínimo por columna
data.min()
# Out:
# nombres                 Ana Tobón
# sexo                            F
# edad                         20.0
# peso                           60
# nueva_variable     Rango 1: 18-24
# nueva_variable2               NaN
# edad_dias                  7300.0
# dtype: object

# %%
# Dato máximo por columna
data.edad_dias.max()
# Out:
# np.float64(18980.0)

# %%
data
# Out:
#             nombres sexo  edad  peso  nueva_variable  nueva_variable2  \
# 0      Jose Urrutia    M  24.0    75  Rango 1: 18-24              NaN
# 1  Esteban Carvajal    M  25.0    80  Rango 2: 25-32              NaN
# 2       Elena Gómez    F  32.0    60  Rango 2: 25-32              NaN
# 3         Ana Tobón    F  45.0    86  Rango 3: 33-54              NaN
# 4      Julian Pardo    M  52.0    72  Rango 3: 33-54              NaN
# 5        Juan Lopez    M  20.0    70  Rango 1: 18-24              NaN
#
#    edad_dias
# 0     8760.0
# 1     9125.0
# 2    11680.0
# 3    16425.0
# 4    18980.0
# 5     7300.0

# %%
# ¿Cuál es el id de la persona que tiene la edad mínima?
data.edad.idxmin()
# Out:
# 5

# %%
# Juan López tiene la edad mínima
data.iloc[data.edad.idxmin(),]
# Out:
# nombres                Juan Lopez
# sexo                            M
# edad                         20.0
# peso                           70
# nueva_variable     Rango 1: 18-24
# nueva_variable2               NaN
# edad_dias                  7300.0
# Name: 5, dtype: object

# %%
# ¿Cuál es el índice de la persona con mayor peso?
data.peso.idxmax()
# Out:
# 3

# %%
data.loc[data.peso.idxmax(),]
# Out:
# nombres                 Ana Tobón
# sexo                            F
# edad                         45.0
# peso                           86
# nueva_variable     Rango 3: 33-54
# nueva_variable2               NaN
# edad_dias                 16425.0
# Name: 3, dtype: object

# %%
data
# Out:
#             nombres sexo  edad  peso  nueva_variable  nueva_variable2  \
# 0      Jose Urrutia    M  24.0    75  Rango 1: 18-24              NaN
# 1  Esteban Carvajal    M  25.0    80  Rango 2: 25-32              NaN
# 2       Elena Gómez    F  32.0    60  Rango 2: 25-32              NaN
# 3         Ana Tobón    F  45.0    86  Rango 3: 33-54              NaN
# 4      Julian Pardo    M  52.0    72  Rango 3: 33-54              NaN
# 5        Juan Lopez    M  20.0    70  Rango 1: 18-24              NaN
#
#    edad_dias
# 0     8760.0
# 1     9125.0
# 2    11680.0
# 3    16425.0
# 4    18980.0
# 5     7300.0

# %%
# Media de las variables
data.mean(numeric_only = True)
# Out:
# edad                  33.000000
# peso                  73.833333
# nueva_variable2             NaN
# edad_dias          12045.000000
# dtype: float64

# %%
data
# Out:
#             nombres sexo  edad  peso  nueva_variable  nueva_variable2  \
# 0      Jose Urrutia    M  24.0    75  Rango 1: 18-24              NaN
# 1  Esteban Carvajal    M  25.0    80  Rango 2: 25-32              NaN
# 2       Elena Gómez    F  32.0    60  Rango 2: 25-32              NaN
# 3         Ana Tobón    F  45.0    86  Rango 3: 33-54              NaN
# 4      Julian Pardo    M  52.0    72  Rango 3: 33-54              NaN
# 5        Juan Lopez    M  20.0    70  Rango 1: 18-24              NaN
#
#    edad_dias
# 0     8760.0
# 1     9125.0
# 2    11680.0
# 3    16425.0
# 4    18980.0
# 5     7300.0

# %%
# Datos medianos
data.median(numeric_only = True)
# Out:
# edad                  28.5
# peso                  73.5
# nueva_variable2        NaN
# edad_dias          10402.5
# dtype: float64

# %%
data.reset_index(inplace=True)

# %%
data
# Out:
#    index           nombres sexo  edad  peso  nueva_variable  nueva_variable2  \
# 0      0      Jose Urrutia    M  24.0    75  Rango 1: 18-24              NaN
# 1      1  Esteban Carvajal    M  25.0    80  Rango 2: 25-32              NaN
# 2      2       Elena Gómez    F  32.0    60  Rango 2: 25-32              NaN
# 3      3         Ana Tobón    F  45.0    86  Rango 3: 33-54              NaN
# 4      4      Julian Pardo    M  52.0    72  Rango 3: 33-54              NaN
# 5      5        Juan Lopez    M  20.0    70  Rango 1: 18-24              NaN
#
#    edad_dias
# 0     8760.0
# 1     9125.0
# 2    11680.0
# 3    16425.0
# 4    18980.0
# 5     7300.0

# %%
data['nombres'] = data['nombres'] + ' López'

# %%
data
# Out:
#    index                 nombres sexo  edad  peso  nueva_variable  \
# 0      0      Jose Urrutia López    M  24.0    75  Rango 1: 18-24
# 1      1  Esteban Carvajal López    M  25.0    80  Rango 2: 25-32
# 2      2       Elena Gómez López    F  32.0    60  Rango 2: 25-32
# 3      3         Ana Tobón López    F  45.0    86  Rango 3: 33-54
# 4      4      Julian Pardo López    M  52.0    72  Rango 3: 33-54
# 5      5        Juan Lopez López    M  20.0    70  Rango 1: 18-24
#
#    nueva_variable2  edad_dias
# 0              NaN     8760.0
# 1              NaN     9125.0
# 2              NaN    11680.0
# 3              NaN    16425.0
# 4              NaN    18980.0
# 5              NaN     7300.0

# %%
data.set_index('nombres')
# Out:
#                         index sexo  edad  peso  nueva_variable  \
# nombres
# Jose Urrutia López          0    M  24.0    75  Rango 1: 18-24
# Esteban Carvajal López      1    M  25.0    80  Rango 2: 25-32
# Elena Gómez López           2    F  32.0    60  Rango 2: 25-32
# Ana Tobón López             3    F  45.0    86  Rango 3: 33-54
# Julian Pardo López          4    M  52.0    72  Rango 3: 33-54
# Juan Lopez López            5    M  20.0    70  Rango 1: 18-24
#
#                         nueva_variable2  edad_dias
# nombres
# Jose Urrutia López                  NaN     8760.0
# Esteban Carvajal López              NaN     9125.0
# Elena Gómez López                   NaN    11680.0
# Ana Tobón López                     NaN    16425.0
# Julian Pardo López                  NaN    18980.0
# Juan Lopez López                    NaN     7300.0

# %% [markdown]
# ### Aplicar funciones a las columnas
# En Pandas, el método `apply` se utiliza para aplicar una función a una serie o a un dataframe. El método `apply` toma como argumento una función y la aplica a cada elemento de la serie o del dataframe, devolviendo una nueva serie o dataframe con los resultados de la función aplicada a cada elemento.
#
# La función que se aplica en el método `apply` puede ser una función lambda o una función definida por el usuario. Esta función debe tomar como argumento un elemento de la serie o dataframe y devolver el resultado de aplicar la función al elemento.
#
# El método `apply` se puede aplicar de varias formas en un dataframe:
#
# - Aplicar una función a una columna específica: Se puede utilizar el método `apply` en una columna específica de un dataframe utilizando la siguiente sintaxis:
#
# ```python
# dataframe["nombre_columna"].apply(funcion)
# ```
#
# Donde "nombre_columna" es el nombre de la columna en la que se desea aplicar la función y "funcion" es la función que se desea aplicar a cada elemento de la columna.
#
# - Aplicar una función a un dataframe completo: Se puede utilizar el método `apply` en un dataframe completo utilizando la siguiente sintaxis:
#
# ```python
# dataframe.apply(funcion)
# ```
#
# Donde "funcion" es la función que se desea aplicar a cada elemento del dataframe.
#
# - Aplicar una función a una fila específica: Se puede utilizar el método `apply` en una fila específica de un dataframe utilizando la siguiente sintaxis:
#
# ```python
# dataframe.loc[etiqueta_fila].apply(funcion)
# ```
#
# Donde "etiqueta_fila" es la etiqueta de la fila en la que se desea aplicar la función y "funcion" es la función que se desea aplicar a cada elemento de la fila.
#
# - el método `apply` también puede ser utilizado con funciones **lambda**, que son funciones anónimas y pequeñas que se definen dentro de una línea de código. Por ejemplo, si se quisiera aplicar una función **lambda** que tome como entrada una cadena de caracteres y devuelva la versión en mayúsculas de la misma, se podría utilizar el método apply de la siguiente manera:
#
# ```python
# dataframe['nombre_columna'].apply(lambda x: x.upper())
# ```
#
# <center>
# <div>
# <img src="img/lambda.png" width="200"/>
# </div>
#
# <div>
# <img src="img/lambda1.png" width="200"/>
# </div>
# </center>
#
# El método `apply` también puede aplicarse a múltiples columnas o filas utilizando la opción axis. Si `axis=0`, la función se aplicará a cada columna del dataframe. Si `axis=1`, la función se aplicará a cada fila del dataframe.
#
# En resumen, el método `apply` se utiliza en Pandas para aplicar una función a una serie o dataframe, y puede utilizarse de diferentes maneras para aplicar la función.

# %%
data
# Out:
#    index                 nombres sexo  edad  peso  nueva_variable  \
# 0      0      Jose Urrutia López    M  24.0    75  Rango 1: 18-24
# 1      1  Esteban Carvajal López    M  25.0    80  Rango 2: 25-32
# 2      2       Elena Gómez López    F  32.0    60  Rango 2: 25-32
# 3      3         Ana Tobón López    F  45.0    86  Rango 3: 33-54
# 4      4      Julian Pardo López    M  52.0    72  Rango 3: 33-54
# 5      5        Juan Lopez López    M  20.0    70  Rango 1: 18-24
#
#    nueva_variable2  edad_dias
# 0              NaN     8760.0
# 1              NaN     9125.0
# 2              NaN    11680.0
# 3              NaN    16425.0
# 4              NaN    18980.0
# 5              NaN     7300.0

# %%
# Multiplicar x 2 todas las celdas
data.apply(lambda numero_x: numero_x*2)
# Out:
#    index                                       nombres sexo   edad  peso  \
# 0      0          Jose Urrutia LópezJose Urrutia López   MM   48.0   150
# 1      2  Esteban Carvajal LópezEsteban Carvajal López   MM   50.0   160
# 2      4            Elena Gómez LópezElena Gómez López   FF   64.0   120
# 3      6                Ana Tobón LópezAna Tobón López   FF   90.0   172
# 4      8          Julian Pardo LópezJulian Pardo López   MM  104.0   144
# 5     10              Juan Lopez LópezJuan Lopez López   MM   40.0   140
#
#                  nueva_variable  nueva_variable2  edad_dias
# 0  Rango 1: 18-24Rango 1: 18-24              NaN    17520.0
# 1  Rango 2: 25-32Rango 2: 25-32              NaN    18250.0
# 2  Rango 2: 25-32Rango 2: 25-32              NaN    23360.0
# 3  Rango 3: 33-54Rango 3: 33-54              NaN    32850.0
# 4  Rango 3: 33-54Rango 3: 33-54              NaN    37960.0
# 5  Rango 1: 18-24Rango 1: 18-24              NaN    14600.0

# %%
def multiplicar_x_2(x):
    return x*2

# %%
multiplicar_x_2(5)
# Out:
# 10

# %%
data.apply(multiplicar_x_2)
# Out:
#    index                                       nombres sexo   edad  peso  \
# 0      0          Jose Urrutia LópezJose Urrutia López   MM   48.0   150
# 1      2  Esteban Carvajal LópezEsteban Carvajal López   MM   50.0   160
# 2      4            Elena Gómez LópezElena Gómez López   FF   64.0   120
# 3      6                Ana Tobón LópezAna Tobón López   FF   90.0   172
# 4      8          Julian Pardo LópezJulian Pardo López   MM  104.0   144
# 5     10              Juan Lopez LópezJuan Lopez López   MM   40.0   140
#
#                  nueva_variable  nueva_variable2  edad_dias
# 0  Rango 1: 18-24Rango 1: 18-24              NaN    17520.0
# 1  Rango 2: 25-32Rango 2: 25-32              NaN    18250.0
# 2  Rango 2: 25-32Rango 2: 25-32              NaN    23360.0
# 3  Rango 3: 33-54Rango 3: 33-54              NaN    32850.0
# 4  Rango 3: 33-54Rango 3: 33-54              NaN    37960.0
# 5  Rango 1: 18-24Rango 1: 18-24              NaN    14600.0

# %%
data
# Out:
#    index                 nombres sexo  edad  peso  nueva_variable  \
# 0      0      Jose Urrutia López    M  24.0    75  Rango 1: 18-24
# 1      1  Esteban Carvajal López    M  25.0    80  Rango 2: 25-32
# 2      2       Elena Gómez López    F  32.0    60  Rango 2: 25-32
# 3      3         Ana Tobón López    F  45.0    86  Rango 3: 33-54
# 4      4      Julian Pardo López    M  52.0    72  Rango 3: 33-54
# 5      5        Juan Lopez López    M  20.0    70  Rango 1: 18-24
#
#    nueva_variable2  edad_dias
# 0              NaN     8760.0
# 1              NaN     9125.0
# 2              NaN    11680.0
# 3              NaN    16425.0
# 4              NaN    18980.0
# 5              NaN     7300.0

# %%
# Convertir la edad de días a años
data["edad_dias"].apply(lambda x: x/365)
# Out:
# 0    24.0
# 1    25.0
# 2    32.0
# 3    45.0
# 4    52.0
# 5    20.0
# Name: edad_dias, dtype: float64

# %%
def funcion_ayuda(x):
    return x/365

# %%
data.edad_dias.apply(funcion_ayuda)
# Out:
# 0    24.0
# 1    25.0
# 2    32.0
# 3    45.0
# 4    52.0
# 5    20.0
# Name: edad_dias, dtype: float64

# %%
data
# Out:
#    index                 nombres sexo  edad  peso  nueva_variable  \
# 0      0      Jose Urrutia López    M  24.0    75  Rango 1: 18-24
# 1      1  Esteban Carvajal López    M  25.0    80  Rango 2: 25-32
# 2      2       Elena Gómez López    F  32.0    60  Rango 2: 25-32
# 3      3         Ana Tobón López    F  45.0    86  Rango 3: 33-54
# 4      4      Julian Pardo López    M  52.0    72  Rango 3: 33-54
# 5      5        Juan Lopez López    M  20.0    70  Rango 1: 18-24
#
#    nueva_variable2  edad_dias
# 0              NaN     8760.0
# 1              NaN     9125.0
# 2              NaN    11680.0
# 3              NaN    16425.0
# 4              NaN    18980.0
# 5              NaN     7300.0

# %%
data[['edad','peso']].apply(np.mean)
# Out:
# edad    33.000000
# peso    73.833333
# dtype: float64

# %%
data[['edad','peso']].max()
# Out:
# edad    52.0
# peso    86.0
# dtype: float64

# %%
data[['edad','peso']].mean()
# Out:
# edad    33.000000
# peso    73.833333
# dtype: float64

# %% [markdown]
# ### Eliminar filas y columnas

# %%
data
# Out:
#    index                 nombres sexo  edad  peso  nueva_variable  \
# 0      0      Jose Urrutia López    M  24.0    75  Rango 1: 18-24
# 1      1  Esteban Carvajal López    M  25.0    80  Rango 2: 25-32
# 2      2       Elena Gómez López    F  32.0    60  Rango 2: 25-32
# 3      3         Ana Tobón López    F  45.0    86  Rango 3: 33-54
# 4      4      Julian Pardo López    M  52.0    72  Rango 3: 33-54
# 5      5        Juan Lopez López    M  20.0    70  Rango 1: 18-24
#
#    nueva_variable2  edad_dias
# 0              NaN     8760.0
# 1              NaN     9125.0
# 2              NaN    11680.0
# 3              NaN    16425.0
# 4              NaN    18980.0
# 5              NaN     7300.0

# %%
data
# Out:
#    index                 nombres sexo  edad  peso  nueva_variable  \
# 0      0      Jose Urrutia López    M  24.0    75  Rango 1: 18-24
# 1      1  Esteban Carvajal López    M  25.0    80  Rango 2: 25-32
# 2      2       Elena Gómez López    F  32.0    60  Rango 2: 25-32
# 3      3         Ana Tobón López    F  45.0    86  Rango 3: 33-54
# 4      4      Julian Pardo López    M  52.0    72  Rango 3: 33-54
# 5      5        Juan Lopez López    M  20.0    70  Rango 1: 18-24
#
#    nueva_variable2  edad_dias
# 0              NaN     8760.0
# 1              NaN     9125.0
# 2              NaN    11680.0
# 3              NaN    16425.0
# 4              NaN    18980.0
# 5              NaN     7300.0

# %%
# Borre la fila identificada como 1
data.drop(1)
# Out:
#    index             nombres sexo  edad  peso  nueva_variable  \
# 0      0  Jose Urrutia López    M  24.0    75  Rango 1: 18-24
# 2      2   Elena Gómez López    F  32.0    60  Rango 2: 25-32
# 3      3     Ana Tobón López    F  45.0    86  Rango 3: 33-54
# 4      4  Julian Pardo López    M  52.0    72  Rango 3: 33-54
# 5      5    Juan Lopez López    M  20.0    70  Rango 1: 18-24
#
#    nueva_variable2  edad_dias
# 0              NaN     8760.0
# 2              NaN    11680.0
# 3              NaN    16425.0
# 4              NaN    18980.0
# 5              NaN     7300.0

# %%
# Borre la columna nueva_variable y nueva_variable2
data.drop(columns = ["index", "nueva_variable2"], inplace = True)

# %%
data
# Out:
#                   nombres sexo  edad  peso  nueva_variable  edad_dias
# 0      Jose Urrutia López    M  24.0    75  Rango 1: 18-24     8760.0
# 1  Esteban Carvajal López    M  25.0    80  Rango 2: 25-32     9125.0
# 2       Elena Gómez López    F  32.0    60  Rango 2: 25-32    11680.0
# 3         Ana Tobón López    F  45.0    86  Rango 3: 33-54    16425.0
# 4      Julian Pardo López    M  52.0    72  Rango 3: 33-54    18980.0
# 5        Juan Lopez López    M  20.0    70  Rango 1: 18-24     7300.0

# %%
# Creemos un valor faltante
data.loc[0, "nombres"] = np.nan
data.loc[2, "peso"] = np.nan

# %%
data
# Out:
#                   nombres sexo  edad  peso  nueva_variable  edad_dias
# 0                     NaN    M  24.0  75.0  Rango 1: 18-24     8760.0
# 1  Esteban Carvajal López    M  25.0  80.0  Rango 2: 25-32     9125.0
# 2       Elena Gómez López    F  32.0   NaN  Rango 2: 25-32    11680.0
# 3         Ana Tobón López    F  45.0  86.0  Rango 3: 33-54    16425.0
# 4      Julian Pardo López    M  52.0  72.0  Rango 3: 33-54    18980.0
# 5        Juan Lopez López    M  20.0  70.0  Rango 1: 18-24     7300.0

# %%
# Eliminamos las filas con valores faltantes
data.dropna()
# Out:
#                   nombres sexo  edad  peso  nueva_variable  edad_dias
# 1  Esteban Carvajal López    M  25.0  80.0  Rango 2: 25-32     9125.0
# 3         Ana Tobón López    F  45.0  86.0  Rango 3: 33-54    16425.0
# 4      Julian Pardo López    M  52.0  72.0  Rango 3: 33-54    18980.0
# 5        Juan Lopez López    M  20.0  70.0  Rango 1: 18-24     7300.0

# %%
data.dropna(subset=['peso'])
# Out:
#                   nombres sexo  edad  peso  nueva_variable  edad_dias
# 0                     NaN    M  24.0  75.0  Rango 1: 18-24     8760.0
# 1  Esteban Carvajal López    M  25.0  80.0  Rango 2: 25-32     9125.0
# 3         Ana Tobón López    F  45.0  86.0  Rango 3: 33-54    16425.0
# 4      Julian Pardo López    M  52.0  72.0  Rango 3: 33-54    18980.0
# 5        Juan Lopez López    M  20.0  70.0  Rango 1: 18-24     7300.0

# %%
data.count()
# Out:
# nombres           5
# sexo              6
# edad              6
# peso              5
# nueva_variable    6
# edad_dias         6
# dtype: int64

# %%
data.isna().sum()
# Out:
# nombres           1
# sexo              0
# edad              0
# peso              1
# nueva_variable    0
# edad_dias         0
# dtype: int64

# %%
data.isna().mean()
# Out:
# nombres           0.166667
# sexo              0.000000
# edad              0.000000
# peso              0.166667
# nueva_variable    0.000000
# edad_dias         0.000000
# dtype: float64

# %% [markdown]
# La función `pd.concat` en Pandas se utiliza para concatenar dos o más objetos de Pandas a lo largo de un eje específico. Los objetos de Pandas pueden ser dataframes o series. La concatenación implica unir los objetos uno al lado del otro o uno debajo del otro, dependiendo del eje especificado.
#
# La sintaxis básica de `pd.concat` es la siguiente:
# ```python
# pd.concat(objetos, axis = 0, join = 'outer', ignore_index = False)
# ```
# Donde:
#
# - `objetos`: es una lista o tupla de objetos de Pandas que se desea concatenar.
# - `axis`: especifica el eje a lo largo del cual se realizará la concatenación. Si `axis=0`, se concatenarán los objetos uno debajo del otro (verticalmente). Si `axis=1`, se concatenarán los objetos uno al lado del otro (horizontalmente).
# - `join`: especifica el tipo de unión que se desea realizar. Puede ser `'inner'` (intersección de los índices), `'outer'` (unión de los índices) o `'left'` (unión de los índices del objeto en el lado izquierdo).
# - `ignore_index`: especifica si se deben ignorar los índices originales y crear nuevos índices. Si es `True`, se crearán nuevos índices.
#
# La función `pd.concat` **es muy útil para combinar dataframes o series que tienen columnas o índices en común**. Por ejemplo, si se tienen dos dataframes que comparten las mismas columnas y se desea combinarlos verticalmente, se podría utilizar el siguiente código:

# %%
df1 = pd.DataFrame({'A': [1, 2], 'B': [3, 4]})
df1
# Out:
#    A  B
# 0  1  3
# 1  2  4

# %%
df2 = pd.DataFrame({'B': [5, 6], 'A': [7, 8]})
df2
# Out:
#    B  A
# 0  5  7
# 1  6  8

# %%
nuevo_df = pd.concat([df1, df2], axis=0)
nuevo_df.reset_index(drop=True)
# Out:
#    A  B
# 0  1  3
# 1  2  4
# 2  7  5
# 3  8  6

# %% [markdown]
# En este caso, se utilizará `axis=0` para concatenar los dataframes verticalmente. Los índices de los dataframes originales se conservarán en el nuevo dataframe.
#
# La función `pd.concat` también puede ser utilizada para combinar dataframes o series que no tienen columnas o índices en común. En este caso, las columnas o índices faltantes se rellenarán con valores nulos. Por ejemplo, si se quisiera combinar horizontalmente dos dataframes que tienen diferentes columnas, se podría utilizar el siguiente código:

# %%
df1 = pd.DataFrame({'Edad': [10, 20], 'Peso': [30, 40]})
df1
# Out:
#    Edad  Peso
# 0    10    30
# 1    20    40

# %%
df2 = pd.DataFrame({'Número de hermanos': [5, 6], 'Escolaridad': ["primaria", "Bachillerato"]})
df2
# Out:
#    Número de hermanos   Escolaridad
# 0                   5      primaria
# 1                   6  Bachillerato

# %%
nuevo_df = pd.concat([df1, df2], axis=1) ### OJO
nuevo_df
# Out:
#    Edad  Peso  Número de hermanos   Escolaridad
# 0    10    30                   5      primaria
# 1    20    40                   6  Bachillerato

# %% [markdown]
# En este caso, se utilizará `axis=1` para concatenar los dataframes horizontalmente. Como los dataframes no tienen columnas en común, se crearán nuevas columnas con valores nulos.
#
# En resumen, la función `pd.concat` en Pandas es una herramienta muy útil para combinar dataframes o series a lo largo de un eje específico. Se puede utilizar con diferentes parámetros para personalizar la unión de los objetos y crear un nuevo dataframe o serie.

# %%
data
# Out:
#                   nombres sexo  edad  peso  nueva_variable  edad_dias
# 0                     NaN    M  24.0  75.0  Rango 1: 18-24     8760.0
# 1  Esteban Carvajal López    M  25.0  80.0  Rango 2: 25-32     9125.0
# 2       Elena Gómez López    F  32.0   NaN  Rango 2: 25-32    11680.0
# 3         Ana Tobón López    F  45.0  86.0  Rango 3: 33-54    16425.0
# 4      Julian Pardo López    M  52.0  72.0  Rango 3: 33-54    18980.0
# 5        Juan Lopez López    M  20.0  70.0  Rango 1: 18-24     7300.0

# %%
# Creemos una nueva fila
nueva_fila = pd.DataFrame({"nombres": "Andrea Saldarriaga", "sexo": "F", "edad": 32, "peso": 60,'nueva_variable':'Rango 2: 25-32','edad_dias':12000}, index = [0])

# %%
nueva_fila
# Out:
#               nombres sexo  edad  peso  nueva_variable  edad_dias
# 0  Andrea Saldarriaga    F    32    60  Rango 2: 25-32      12000

# %%
data = pd.concat((data, nueva_fila), axis = 0)
data
# Out:
#                   nombres sexo  edad  peso  nueva_variable  edad_dias
# 0                     NaN    M  24.0  75.0  Rango 1: 18-24     8760.0
# 1  Esteban Carvajal López    M  25.0  80.0  Rango 2: 25-32     9125.0
# 2       Elena Gómez López    F  32.0   NaN  Rango 2: 25-32    11680.0
# 3         Ana Tobón López    F  45.0  86.0  Rango 3: 33-54    16425.0
# 4      Julian Pardo López    M  52.0  72.0  Rango 3: 33-54    18980.0
# 5        Juan Lopez López    M  20.0  70.0  Rango 1: 18-24     7300.0
# 0      Andrea Saldarriaga    F  32.0  60.0  Rango 2: 25-32    12000.0

# %%
# Creemos una fila duplicada
data = pd.concat((data, data.iloc[1:2,]), axis = 0)

# %%
data
# Out:
#                   nombres sexo  edad  peso  nueva_variable  edad_dias
# 0                     NaN    M  24.0  75.0  Rango 1: 18-24     8760.0
# 1  Esteban Carvajal López    M  25.0  80.0  Rango 2: 25-32     9125.0
# 2       Elena Gómez López    F  32.0   NaN  Rango 2: 25-32    11680.0
# 3         Ana Tobón López    F  45.0  86.0  Rango 3: 33-54    16425.0
# 4      Julian Pardo López    M  52.0  72.0  Rango 3: 33-54    18980.0
# 5        Juan Lopez López    M  20.0  70.0  Rango 1: 18-24     7300.0
# 0      Andrea Saldarriaga    F  32.0  60.0  Rango 2: 25-32    12000.0
# 1  Esteban Carvajal López    M  25.0  80.0  Rango 2: 25-32     9125.0

# %%
data.loc[data.duplicated(subset="nombres")]
# Out:
#                   nombres sexo  edad  peso  nueva_variable  edad_dias
# 1  Esteban Carvajal López    M  25.0  80.0  Rango 2: 25-32     9125.0

# %%
data.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 0    False
# 1     True
# dtype: bool

# %%
# Eliminemos duplicados. Conserva la primera observación
data = data.drop_duplicates()
data
# Out:
#                   nombres sexo  edad  peso  nueva_variable  edad_dias
# 0                     NaN    M  24.0  75.0  Rango 1: 18-24     8760.0
# 1  Esteban Carvajal López    M  25.0  80.0  Rango 2: 25-32     9125.0
# 2       Elena Gómez López    F  32.0   NaN  Rango 2: 25-32    11680.0
# 3         Ana Tobón López    F  45.0  86.0  Rango 3: 33-54    16425.0
# 4      Julian Pardo López    M  52.0  72.0  Rango 3: 33-54    18980.0
# 5        Juan Lopez López    M  20.0  70.0  Rango 1: 18-24     7300.0
# 0      Andrea Saldarriaga    F  32.0  60.0  Rango 2: 25-32    12000.0

# %%
data.reset_index(drop=True,inplace=True)
data
# Out:
#                   nombres sexo  edad  peso  nueva_variable  edad_dias
# 0                     NaN    M  24.0  75.0  Rango 1: 18-24     8760.0
# 1  Esteban Carvajal López    M  25.0  80.0  Rango 2: 25-32     9125.0
# 2       Elena Gómez López    F  32.0   NaN  Rango 2: 25-32    11680.0
# 3         Ana Tobón López    F  45.0  86.0  Rango 3: 33-54    16425.0
# 4      Julian Pardo López    M  52.0  72.0  Rango 3: 33-54    18980.0
# 5        Juan Lopez López    M  20.0  70.0  Rango 1: 18-24     7300.0
# 6      Andrea Saldarriaga    F  32.0  60.0  Rango 2: 25-32    12000.0

# %%
data2 = pd.DataFrame({'direccion':['Cra 14','Calle 3','Carrera 4','Calle 72','Carrera 24','Calle 127']})

# %%
data2
# Out:
#     direccion
# 0      Cra 14
# 1     Calle 3
# 2   Carrera 4
# 3    Calle 72
# 4  Carrera 24
# 5   Calle 127

# %%
pd.concat([data,data2],axis=1) ###ADVERTENCIA
# Out:
#                   nombres sexo  edad  peso  nueva_variable  edad_dias  \
# 0                     NaN    M  24.0  75.0  Rango 1: 18-24     8760.0
# 1  Esteban Carvajal López    M  25.0  80.0  Rango 2: 25-32     9125.0
# 2       Elena Gómez López    F  32.0   NaN  Rango 2: 25-32    11680.0
# 3         Ana Tobón López    F  45.0  86.0  Rango 3: 33-54    16425.0
# 4      Julian Pardo López    M  52.0  72.0  Rango 3: 33-54    18980.0
# 5        Juan Lopez López    M  20.0  70.0  Rango 1: 18-24     7300.0
# 6      Andrea Saldarriaga    F  32.0  60.0  Rango 2: 25-32    12000.0
#
#     direccion
# 0      Cra 14
# 1     Calle 3
# 2   Carrera 4
# 3    Calle 72
# 4  Carrera 24
# 5   Calle 127
# 6         NaN

# %%
data.drop_duplicates(subset='sexo')
# Out:
#              nombres sexo  edad  peso  nueva_variable  edad_dias
# 0                NaN    M  24.0  75.0  Rango 1: 18-24     8760.0
# 2  Elena Gómez López    F  32.0   NaN  Rango 2: 25-32    11680.0

# %%
data
# Out:
#                   nombres sexo  edad  peso  nueva_variable  edad_dias
# 0                     NaN    M  24.0  75.0  Rango 1: 18-24     8760.0
# 1  Esteban Carvajal López    M  25.0  80.0  Rango 2: 25-32     9125.0
# 2       Elena Gómez López    F  32.0   NaN  Rango 2: 25-32    11680.0
# 3         Ana Tobón López    F  45.0  86.0  Rango 3: 33-54    16425.0
# 4      Julian Pardo López    M  52.0  72.0  Rango 3: 33-54    18980.0
# 5        Juan Lopez López    M  20.0  70.0  Rango 1: 18-24     7300.0
# 6      Andrea Saldarriaga    F  32.0  60.0  Rango 2: 25-32    12000.0

# %%
data2
# Out:
#     direccion
# 0      Cra 14
# 1     Calle 3
# 2   Carrera 4
# 3    Calle 72
# 4  Carrera 24
# 5   Calle 127

# %%
pd.concat([data,data2],axis=1)
# Out:
#                   nombres sexo  edad  peso  nueva_variable  edad_dias  \
# 0                     NaN    M  24.0  75.0  Rango 1: 18-24     8760.0
# 1  Esteban Carvajal López    M  25.0  80.0  Rango 2: 25-32     9125.0
# 2       Elena Gómez López    F  32.0   NaN  Rango 2: 25-32    11680.0
# 3         Ana Tobón López    F  45.0  86.0  Rango 3: 33-54    16425.0
# 4      Julian Pardo López    M  52.0  72.0  Rango 3: 33-54    18980.0
# 5        Juan Lopez López    M  20.0  70.0  Rango 1: 18-24     7300.0
# 6      Andrea Saldarriaga    F  32.0  60.0  Rango 2: 25-32    12000.0
#
#     direccion
# 0      Cra 14
# 1     Calle 3
# 2   Carrera 4
# 3    Calle 72
# 4  Carrera 24
# 5   Calle 127
# 6         NaN

# %% [markdown]
# ## Ejercicio 1
#
# Para el siguiente ejercicio, usted importará el archivo `consumo_masivo_col.xslx`. Este dataset contiene los productos disponibles en los dos supermercados más grandes de Colombia, en el se incluye la marca, producto, precio en diferentes puntos de corte durante el año 2019. Primero, una introducción a como leer este archivo.

# %%
# !pip3 install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\santiago neira\appdata\local\programs\python\python311\lib\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in c:\users\santiago neira\appdata\local\programs\python\python311\lib\site-packages (from openpyxl) (2.0.0)
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#ruta_archivo = '/content/consumo_masivo_col.xlsx' #Para GoogleColab
ruta_archivo = './datos/consumo_masivo_col.xlsx' #Para local
productos_consumo_masivo = pd.read_excel(ruta_archivo)

# %%
productos_consumo_masivo.head()
# Out:
#        date        prod_id                                          prod_name  \
# 0  20190609  7702155021451                 Limpia tapicería en espuma Binner
# 1  20190609  7702155016457               Limpia tapicería y alfombras Binner
# 2  20190609  4008455446318   Limpiador Dr. Beckmann alfombras 2en1 poder oxi
# 3  20190609  7702532312677          Aceite Bon Aire eléctrico perfume flores
# 4  20190609  7702532312967  Ambientador Aire Varitas Bambú Bonaire 2 Repue...
#
#                                       prod_name_long   prod_brand  \
# 0          Limpia tapicería en espuma Binner x 400ml       BINNER
# 1        Limpia tapicería y alfombras Binner x 500ml       BINNER
# 2  Limpiador Dr. Beckmann alfombras 2en1 poder ox...  DR.BECKMANN
# 3   Aceite Bon Aire eléctrico perfume flores x 25 ml      BONAIRE
# 4  Ambientador Aire Varitas Bambú Bonaire 2 Repue...      BONAIRE
#
#        category    subcategory           tags prod_unit_price prod_units  \
# 0  Supermercado  Aseo de hogar      Alfombras           15590   Unidades
# 1  Supermercado  Aseo de hogar      Alfombras           13993   Unidades
# 2  Supermercado  Aseo de hogar      Alfombras           16513   Unidades
# 3  Supermercado  Aseo de hogar  Ambientadores           14990   Unidades
# 4  Supermercado  Aseo de hogar  Ambientadores           34990   Unidades
#
#                                    prod_icon prod_source  source_type
# 0          ../icons/SVG/53-places/home-3.svg       VERDE            1
# 1          ../icons/SVG/53-places/home-3.svg       VERDE            1
# 2          ../icons/SVG/53-places/home-3.svg       VERDE            1
# 3  ../icons/SVG/58-beauty-spas/spa-vapor.svg       VERDE            1
# 4  ../icons/SVG/58-beauty-spas/spa-vapor.svg       VERDE            1

# %%
ruta_archivo= r"C:\Users\Santiago Neira\OneDrive - Universidad de los andes\Escritorio\Intro_analisis_datos_EDCO\clase_3\datos\consumo_masivo_col.xlsx"
productos_consumo_masivo = pd.read_excel(ruta_archivo)

# %%
productos_consumo_masivo.head()
# Out:
#        date        prod_id                                          prod_name  \
# 0  20190609  7702155021451                 Limpia tapicería en espuma Binner
# 1  20190609  7702155016457               Limpia tapicería y alfombras Binner
# 2  20190609  4008455446318   Limpiador Dr. Beckmann alfombras 2en1 poder oxi
# 3  20190609  7702532312677          Aceite Bon Aire eléctrico perfume flores
# 4  20190609  7702532312967  Ambientador Aire Varitas Bambú Bonaire 2 Repue...
#
#                                       prod_name_long   prod_brand  \
# 0          Limpia tapicería en espuma Binner x 400ml       BINNER
# 1        Limpia tapicería y alfombras Binner x 500ml       BINNER
# 2  Limpiador Dr. Beckmann alfombras 2en1 poder ox...  DR.BECKMANN
# 3   Aceite Bon Aire eléctrico perfume flores x 25 ml      BONAIRE
# 4  Ambientador Aire Varitas Bambú Bonaire 2 Repue...      BONAIRE
#
#        category    subcategory           tags prod_unit_price prod_units  \
# 0  Supermercado  Aseo de hogar      Alfombras           15590   Unidades
# 1  Supermercado  Aseo de hogar      Alfombras           13993   Unidades
# 2  Supermercado  Aseo de hogar      Alfombras           16513   Unidades
# 3  Supermercado  Aseo de hogar  Ambientadores           14990   Unidades
# 4  Supermercado  Aseo de hogar  Ambientadores           34990   Unidades
#
#                                    prod_icon prod_source  source_type
# 0          ../icons/SVG/53-places/home-3.svg       VERDE            1
# 1          ../icons/SVG/53-places/home-3.svg       VERDE            1
# 2          ../icons/SVG/53-places/home-3.svg       VERDE            1
# 3  ../icons/SVG/58-beauty-spas/spa-vapor.svg       VERDE            1
# 4  ../icons/SVG/58-beauty-spas/spa-vapor.svg       VERDE            1

# %% [markdown]
# #### Accediendo a los archivos a través del paquete os

# %%
import os
os.getcwd()
os.chdir(r"C:\Users\Santiago Neira\OneDrive - Universidad de los andes\Escritorio\Intro_analisis_datos_EDCO\clase_3\datos")
os.getcwd()
# Out:
# 'C:\\Users\\Santiago Neira\\OneDrive - Universidad de los andes\\Escritorio\\Intro_analisis_datos_EDCO\\clase_3\\datos'

# %%
productos_consumo_masivo = pd.read_excel('consumo_masivo_col.xlsx')

# %%
productos_consumo_masivo.head()
# Out:
#        date        prod_id                                          prod_name  \
# 0  20190609  7702155021451                 Limpia tapicería en espuma Binner
# 1  20190609  7702155016457               Limpia tapicería y alfombras Binner
# 2  20190609  4008455446318   Limpiador Dr. Beckmann alfombras 2en1 poder oxi
# 3  20190609  7702532312677          Aceite Bon Aire eléctrico perfume flores
# 4  20190609  7702532312967  Ambientador Aire Varitas Bambú Bonaire 2 Repue...
#
#                                       prod_name_long   prod_brand  \
# 0          Limpia tapicería en espuma Binner x 400ml       BINNER
# 1        Limpia tapicería y alfombras Binner x 500ml       BINNER
# 2  Limpiador Dr. Beckmann alfombras 2en1 poder ox...  DR.BECKMANN
# 3   Aceite Bon Aire eléctrico perfume flores x 25 ml      BONAIRE
# 4  Ambientador Aire Varitas Bambú Bonaire 2 Repue...      BONAIRE
#
#        category    subcategory           tags prod_unit_price prod_units  \
# 0  Supermercado  Aseo de hogar      Alfombras           15590   Unidades
# 1  Supermercado  Aseo de hogar      Alfombras           13993   Unidades
# 2  Supermercado  Aseo de hogar      Alfombras           16513   Unidades
# 3  Supermercado  Aseo de hogar  Ambientadores           14990   Unidades
# 4  Supermercado  Aseo de hogar  Ambientadores           34990   Unidades
#
#                                    prod_icon prod_source  source_type
# 0          ../icons/SVG/53-places/home-3.svg       VERDE            1
# 1          ../icons/SVG/53-places/home-3.svg       VERDE            1
# 2          ../icons/SVG/53-places/home-3.svg       VERDE            1
# 3  ../icons/SVG/58-beauty-spas/spa-vapor.svg       VERDE            1
# 4  ../icons/SVG/58-beauty-spas/spa-vapor.svg       VERDE            1

# %%
productos_consumo_masivo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25638 entries, 0 to 25637
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date             25638 non-null  int64
#  1   prod_id          25638 non-null  int64
#  2   prod_name        25506 non-null  object
#  3   prod_name_long   25638 non-null  object
#  4   prod_brand       25586 non-null  object
#  5   category         25638 non-null  object
#  6   subcategory      25638 non-null  object
#  7   tags             25638 non-null  object
#  8   prod_unit_price  25633 non-null  object
#  9   prod_units       25231 non-null  object
#  10  prod_icon        25231 non-null  object
#  11  prod_source      25638 non-null  object
#  12  source_type      25638 non-null  int64
# dtypes: int64(3), object(10)
# memory usage: 2.5+ MB

# %%
productos_consumo_masivo.describe()
# Out:
#                date       prod_id  source_type
# count  2.563800e+04  2.563800e+04      25638.0
# mean   2.019279e+07  7.137052e+12          1.0
# std    3.867261e+03  1.872051e+12          0.0
# min    2.019061e+07  5.244812e+06          1.0
# 25%    2.019061e+07  7.702010e+12          1.0
# 50%    2.019071e+07  7.702177e+12          1.0
# 75%    2.019110e+07  7.703616e+12          1.0
# max    2.020022e+07  9.333527e+12          1.0

# %% [markdown]
# ### Trabajando con fechas al importar un archivo de excel

# %%
productos_consumo_masivo['date'].head()
# Out:
# 0    20190609
# 1    20190609
# 2    20190609
# 3    20190609
# 4    20190609
# Name: date, dtype: int64

# %%
productos_consumo_masivo['date'] = pd.to_datetime(productos_consumo_masivo['date'],format='%Y%m%d')

# %%
productos_consumo_masivo.head(2)
# Out:
#         date        prod_id                             prod_name  \
# 0 2019-06-09  7702155021451    Limpia tapicería en espuma Binner
# 1 2019-06-09  7702155016457  Limpia tapicería y alfombras Binner
#
#                                 prod_name_long prod_brand      category  \
# 0    Limpia tapicería en espuma Binner x 400ml     BINNER  Supermercado
# 1  Limpia tapicería y alfombras Binner x 500ml     BINNER  Supermercado
#
#      subcategory       tags prod_unit_price prod_units  \
# 0  Aseo de hogar  Alfombras           15590   Unidades
# 1  Aseo de hogar  Alfombras           13993   Unidades
#
#                            prod_icon prod_source  source_type
# 0  ../icons/SVG/53-places/home-3.svg       VERDE            1
# 1  ../icons/SVG/53-places/home-3.svg       VERDE            1

# %% [markdown]
# ### Trabajando con valores numéricos al importar un archivo de excel

# %%
productos_consumo_masivo.columns
# Out:
# Index(['date', 'prod_id', 'prod_name', 'prod_name_long', 'prod_brand',
#        'category', 'subcategory', 'tags', 'prod_unit_price', 'prod_units',
#        'prod_icon', 'prod_source', 'source_type'],
#       dtype='object')

# %%
productos_consumo_masivo['prod_unit_price'].head()
# Out:
# 0    15590
# 1    13993
# 2    16513
# 3    14990
# 4    34990
# Name: prod_unit_price, dtype: object

# %%
productos_consumo_masivo['prod_unit_price'].dtype
# Out:
# dtype('O')

# %%
productos_consumo_masivo['prod_unit_price'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[392], line 1
# ----> 1 productos_consumo_masivo['prod_unit_price'].astype(float)
#
# File c:\Users\Santiago Neira\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:6665, in NDFrame.astype(self, dtype, copy, errors)
#    6659     results = [
#    6660         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6661     ]
#    6663 else:
#    6664     # else, only a single dtype is given
# -> 6665     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6666     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6667     return res.__finalize__(self, method="astype")
#
# File c:\Users\Santiago Neira\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:449, in BaseBlockManager.astype(self, dtype, copy, errors)
#     446 elif using_copy_on_write():
#     447     copy = False
# --> 449 return self.apply(
#     450     "astype",
#     451     dtype=dtype,
#     452     copy=copy,
#     453     errors=errors,
#     454     using_cow=using_copy_on_write(),
#     455 )
#
# File c:\Users\Santiago Neira\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File c:\Users\Santiago Neira\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\blocks.py:784, in Block.astype(self, dtype, copy, errors, using_cow, squeeze)
#     781         raise ValueError("Can not squeeze with more than one column.")
#     782     values = values[0, :]  # type: ignore[call-overload]
# --> 784 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     786 new_values = maybe_coerce_values(new_values)
#     788 refs = None
#
# File c:\Users\Santiago Neira\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\dtypes\astype.py:237, in astype_array_safe(values, dtype, copy, errors)
#     234     dtype = dtype.numpy_dtype
#     236 try:
# --> 237     new_values = astype_array(values, dtype, copy=copy)
#     238 except (ValueError, TypeError):
#     239     # e.g. _astype_nansafe can fail on object-dtype of strings
#     240     #  trying to convert to float
#     241     if errors == "ignore":
#
# File c:\Users\Santiago Neira\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\dtypes\astype.py:182, in astype_array(values, dtype, copy)
#     179     values = values.astype(dtype, copy=copy)
#     181 else:
# --> 182     values = _astype_nansafe(values, dtype, copy=copy)
#     184 # in pandas we don't store numpy str dtypes, so convert to object
#     185 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File c:\Users\Santiago Neira\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\dtypes\astype.py:133, in _astype_nansafe(arr, dtype, copy, skipna)
#     129     raise ValueError(msg)
#     131 if copy or arr.dtype == object or dtype == object:
#     132     # Explicit copy, or required since NumPy can't view from / to object.
# --> 133     return arr.astype(dtype, copy=True)
#     135 return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: '70386,95'

# %%
productos_consumo_masivo['prod_unit_price'] = pd.to_numeric(productos_consumo_masivo['prod_unit_price'].astype(str).str.replace(',', '.'),errors='coerce')

# %%
productos_consumo_masivo.head()
# Out:
#         date        prod_id  \
# 0 2019-06-09  7702155021451
# 1 2019-06-09  7702155016457
# 2 2019-06-09  4008455446318
# 3 2019-06-09  7702532312677
# 4 2019-06-09  7702532312967
#
#                                            prod_name  \
# 0                 Limpia tapicería en espuma Binner
# 1               Limpia tapicería y alfombras Binner
# 2   Limpiador Dr. Beckmann alfombras 2en1 poder oxi
# 3          Aceite Bon Aire eléctrico perfume flores
# 4  Ambientador Aire Varitas Bambú Bonaire 2 Repue...
#
#                                       prod_name_long   prod_brand  \
# 0          Limpia tapicería en espuma Binner x 400ml       BINNER
# 1        Limpia tapicería y alfombras Binner x 500ml       BINNER
# 2  Limpiador Dr. Beckmann alfombras 2en1 poder ox...  DR.BECKMANN
# 3   Aceite Bon Aire eléctrico perfume flores x 25 ml      BONAIRE
# 4  Ambientador Aire Varitas Bambú Bonaire 2 Repue...      BONAIRE
#
#        category    subcategory           tags  prod_unit_price prod_units  \
# 0  Supermercado  Aseo de hogar      Alfombras          15590.0   Unidades
# 1  Supermercado  Aseo de hogar      Alfombras          13993.0   Unidades
# 2  Supermercado  Aseo de hogar      Alfombras          16513.0   Unidades
# 3  Supermercado  Aseo de hogar  Ambientadores          14990.0   Unidades
# 4  Supermercado  Aseo de hogar  Ambientadores          34990.0   Unidades
#
#                                    prod_icon prod_source  source_type
# 0          ../icons/SVG/53-places/home-3.svg       VERDE            1
# 1          ../icons/SVG/53-places/home-3.svg       VERDE            1
# 2          ../icons/SVG/53-places/home-3.svg       VERDE            1
# 3  ../icons/SVG/58-beauty-spas/spa-vapor.svg       VERDE            1
# 4  ../icons/SVG/58-beauty-spas/spa-vapor.svg       VERDE            1

# %% [markdown]
# A partir del dataframe anterior, responda las siguientes preguntas:
#
# 1. Antes de iniciar, trate de familiarizarse un poco con la base de datos. ¿Cuántos valores de `subcategory` existen? ¿A qué corresponden? ¿Cuántos valores de `prod_units` existen? ¿A qué corresponden?
# 2. ¿Cuál es el rango de precios que se encuentra en esta base de datos?
# 3. ¿Cuál es el precio promedio de los artículos de cuidado personal?
# 4. ¿Cuáles son  las cinco `Galletas dulces` más costosas del mercado? ¿A qué marcas corresponden?
# 5. ¿Cuáles son las cinco marcas que tienen más productos por debajo de los $10,000 pesos? ¿Cuáles son? Encuentre algunos ejemplos de estos productos.
# 7. ¿Cuántos productos tienen como fecha Febrero de 2020? ¿Cuáles son las dos marcas con más productos en esta fecha?

# %%
productos_consumo_masivo.columns
# Out:
# Index(['date', 'prod_id', 'prod_name', 'prod_name_long', 'prod_brand',
#        'category', 'subcategory', 'tags', 'prod_unit_price', 'prod_units',
#        'prod_icon', 'prod_source', 'source_type'],
#       dtype='object')

# %%
## 1. Valores únicos de subcategory
productos_consumo_masivo['subcategory'].unique()
# Out:
# array(['Aseo de hogar', 'Bebidas', 'Belleza', 'Charcutería',
#        'Cuidado de ropa y calzado', 'Cuidado Personal', 'Despensa',
#        'Dulces y postres', 'Lácteos, huevos y refrigerados',
#        'Limpieza de cocina', 'Panadería y Pastelería', 'Pasabocas',
#        'Productos Congelados', 'Vinos y Licores'], dtype=object)

# %%
## Número de elementos únicos en subcategory
productos_consumo_masivo['subcategory'].nunique()
# Out:
# 14

# %%
productos_consumo_masivo['prod_units'].unique()
# Out:
# array(['Unidades', 'Botella', nan], dtype=object)

# %%
productos_consumo_masivo['prod_units'].nunique()
# Out:
# 2

# %%
###2. Rango de precios de la base de datos
productos_consumo_masivo['prod_unit_price'].describe()
# Out:
# count     25633.000000
# mean      16180.033485
# std       39862.123156
# min           0.000000
# 25%        4190.000000
# 50%        7390.000000
# 75%       13990.000000
# max      990000.000000
# Name: prod_unit_price, dtype: float64

# %%
print(productos_consumo_masivo['prod_unit_price'].min())
print(productos_consumo_masivo['prod_unit_price'].max())
# Out:
# 0.0
# 990000.0

# %%
productos_consumo_masivo.shape
# Out:
# (25638, 13)

# %%
### Precio promedio de los artículos de cuidado personal
base_cuidado_personal = productos_consumo_masivo.loc[productos_consumo_masivo['subcategory']=='Cuidado Personal']
base_cuidado_personal['prod_unit_price'].mean()
# Out:
# np.float64(11360.566067240032)

# %%
#¿Cuáles son  las cinco `Galletas dulces` más costosas del mercado? ¿A qué marcas corresponden?
productos_consumo_masivo['tags'].unique()
# Out:
# array(['Alfombras', 'Ambientadores', 'Blanqueadores', 'Cera',
#        'Desinfectantes', 'Insecticidas', 'Limpieza de superficies',
#        'Limpieza W.C.', 'Multiusos', 'Agua', 'Energizantes', 'Gaseosas',
#        'Hidratantes', 'Jugos, refrescos y maltas', 'Té líquido',
#        'Accesorios de belleza', 'Coloración', 'Cremas corporales',
#        'Cuidado Facial', 'Depilación', 'Maquillaje', 'Protección solar',
#        'Repelentes', 'Carnes frías maduradas y ahumadas',
#        'Encurtidos y otros', 'Quesos especializados', 'Betún',
#        'Desmanchadores', 'Detergentes', 'Jabones de Barra',
#        'Prelavado y preplanchado', 'Suavizantes',
#        'Acondicionadores y tratamientos', 'Afeitado', 'Botiquín',
#        'Cuidado de pies', 'Cuidado Oral', 'Desodorantes',
#        'Gel y Fijadores', 'Jabones de tocador', 'Pañuelos',
#        'Papel higiénico', 'Protección Adulta', 'Protección Femenina',
#        'Shampoo', 'Aceite', 'Arroz y granos', 'Avenas y salvado',
#        'Azúcar, Endulzantes y Panelas', 'Bases, cremas y sopas',
#        'Bebida achocolatada en polvo', 'Café', 'Cereales',
#        'Chocolate de mesa', 'Condimentos, caldos y sal',
#        'Enlatados y conservas', 'Harinas y mezclas para preparar',
#        'Pastas', 'Salsas y vinagres', 'Té, infusiones e instantáneos',
#        'Arequipe', 'Chocolatería', 'Confitería',
#        'Crema leche y leche condensada', 'Dulces típicos',
#        'Gelatinas, flanes y pudines', 'Repostería', 'Arepas', 'Avena',
#        'Carnes frías y embutidos', 'Huevos', 'Kumis', 'Leche',
#        'Leches vegetales', 'Mantequilla', 'Margarina',
#        'Postres refrigerados', 'Queso', 'Tamales', 'Waffles y Crepes',
#        'Yogurt', 'Baldes, escobas y accesorios', 'Bolsas de basura',
#        'Esponjas y fibras', 'Guantes', 'Lavalozas',
#        'Servilletas y papel aluminio', 'Antojos', 'Panadería Artesanal',
#        'Panadería empacada', 'Pastelería', 'Frutos Secos',
#        'Galletas dietéticas y saludables', 'Galletas dulces',
#        'Galletas saladas', 'Mermelada y Cremas de untar',
#        'Papas fritas y paquetes', 'Pasabocas para microondas', 'Apanados',
#        'Empanadas', 'Helados', 'Masas y snacks',
#        'Papas, yucas y patacones', 'Pizza y pastas congeladas',
#        'Verduras Congeladas', 'Aguardiente', 'Aperitivos', 'Brandy',
#        'Cervezas', 'Champañas y espumoso', 'Cognac', 'Ginebra', 'Ron',
#        'Tequilas y piscos', 'Vino', 'Vodka', 'Whisky'], dtype=object)

# %%
dulces=productos_consumo_masivo.loc[productos_consumo_masivo['subcategory']=='Dulces y postres']
dulces['tags'].unique()
# Out:
# array(['Arequipe', 'Chocolatería', 'Confitería',
#        'Crema leche y leche condensada', 'Dulces típicos',
#        'Gelatinas, flanes y pudines', 'Repostería'], dtype=object)

# %%
'Galletas dulces' in productos_consumo_masivo['tags'].values
# Out:
# True

# %%
productos_galletas= productos_consumo_masivo.loc[productos_consumo_masivo['tags']=='Galletas dulces']
productos_galletas.sort_values('prod_unit_price', ascending=False).head(10)
# Out:
#             date        prod_id                               prod_name  \
# 5399  2019-06-09  7591675010508  Barquilla Pirulin chocolate avellanas
# 19157 2019-11-01  7591675010508  Barquilla Pirulin chocolate avellanas
# 13432 2019-07-09  7591675010508  Barquilla Pirulin chocolate avellanas
# 6928  2019-07-09  7466762939010  Barquilla chocolate avellanas Pirulin
# 5377  2019-06-09  8000350001186        Galletas Mini Voglie Vicenzi Bl
# 13410 2019-07-09  8000350001186        Galletas Mini Voglie Vicenzi Bl
# 19136 2019-11-01  8000350001186        Galletas Mini Voglie Vicenzi Bl
# 5368  2019-06-09  4001518450017          Galletas Griesson Café Música
# 19128 2019-11-01  4001518450017          Galletas Griesson Café Música
# 13401 2019-07-09  4001518450017          Galletas Griesson Café Música
#
#                                       prod_name_long prod_brand      category  \
# 5399   Barquilla Pirulin chocolate avellanas x 300 g    PIRULIN  Supermercado
# 19157  Barquilla Pirulin chocolate avellanas x 300 g    PIRULIN  Supermercado
# 13432  Barquilla Pirulin chocolate avellanas x 300 g    PIRULIN  Supermercado
# 6928                          Barquilla Chocolate av    PIRULIN  Supermercado
# 5377           Galletas Mini Voglie Vicenzi Bl x300g    VICENZI  Supermercado
# 13410          Galletas Mini Voglie Vicenzi Bl x300g    VICENZI  Supermercado
# 19136          Galletas Mini Voglie Vicenzi Bl x300g    VICENZI  Supermercado
# 5368            Galletas Griesson Café Música X 200g   GRIESSON  Supermercado
# 19128           Galletas Griesson Café Música X 200g   GRIESSON  Supermercado
# 13401           Galletas Griesson Café Música X 200g   GRIESSON  Supermercado
#
#       subcategory             tags  prod_unit_price prod_units  \
# 5399    Pasabocas  Galletas dulces          21590.0   Unidades
# 19157   Pasabocas  Galletas dulces          21590.0   Unidades
# 13432   Pasabocas  Galletas dulces          21590.0   Unidades
# 6928    Pasabocas  Galletas dulces          16100.0   Unidades
# 5377    Pasabocas  Galletas dulces          15590.0   Unidades
# 13410   Pasabocas  Galletas dulces          15590.0   Unidades
# 19136   Pasabocas  Galletas dulces          15590.0   Unidades
# 5368    Pasabocas  Galletas dulces          14590.0   Unidades
# 19128   Pasabocas  Galletas dulces          14590.0   Unidades
# 13401   Pasabocas  Galletas dulces          14590.0   Unidades
#
#                              prod_icon prod_source  source_type
# 5399   ../icons/SVG/74-food/cookie.svg       VERDE            1
# 19157  ../icons/SVG/74-food/cookie.svg       VERDE            1
# 13432  ../icons/SVG/74-food/cookie.svg       VERDE            1
# 6928   ../icons/SVG/74-food/cookie.svg    AMARILLO            1
# 5377   ../icons/SVG/74-food/cookie.svg       VERDE            1
# 13410  ../icons/SVG/74-food/cookie.svg       VERDE            1
# 19136  ../icons/SVG/74-food/cookie.svg       VERDE            1
# 5368   ../icons/SVG/74-food/cookie.svg       VERDE            1
# 19128  ../icons/SVG/74-food/cookie.svg       VERDE            1
# 13401  ../icons/SVG/74-food/cookie.svg       VERDE            1

# %%
##5. ¿Cuáles son las cinco marcas que tienen más productos por debajo de los $10,000 pesos? ¿Cuáles son? Encuentre algunos ejemplos de estos productos.
productos_bajo_10k= productos_consumo_masivo.loc[productos_consumo_masivo['prod_unit_price']<10000]
productos_bajo_10k.drop_duplicates(subset=['prod_id'])
productos_bajo_10k['prod_brand'].value_counts().head(5)
# Out:
# prod_brand
# VOGUE      667
# COLANTA    439
# ALPINA     413
# JUMBO      286
# MASGLO     258
# Name: count, dtype: int64

# %%
productos_bajo_10k
